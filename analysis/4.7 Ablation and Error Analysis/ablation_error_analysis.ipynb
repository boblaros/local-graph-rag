# %% [markdown]
# # 4.7 Ablation and Error Analysis
#
# ## Data Sources
#
# - `../../runs/analysis/global_experiment_report.34d2c998f8e8143d.json` — Experiment-wide evaluated report; supplies the active artifact registry, model family and parameter metadata, declared regimes, bootstrap contract, and graph/extraction/ER summary metrics.
# - `../../runs/analysis/prespecified_cascade_comparisons.6869b0d1a39bd730.json` — Prespecified cascade comparison artifact; used to validate the declared primary, secondary, and incremental roles and the complete 12-builder comparison coverage.
# - `../../multihoprag_120/questions.jsonl` — Curated 120-question registry; provides question text, type, answerability, and gold answers for recurrent-error review.
# - Per-question evaluated metric files (all active builder–regime cells):
#
#   - `../../runs/variants/variant_er_2b1eb0de0420e8a59f0008ff/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_fa60813adc48b7946504cad9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_c41e9c339aaefbc613be1a13/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_28508ddd03bad1b453b1ac27/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_f6886e1fcfead6531b3c7850/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_4c7fe3e91e1ce688febabbe1/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_8487befcdc34573a74986444/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_9978ad4c0e3c4eab0acc8705/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_2b68fc1e293f9a495f3b40ab/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_6756da7bf5b8ad0e2566fbe9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_c81e35865e785a11de06d57a/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_ed7fe257a2a5d1ca497b9531/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_a622307fd50890d7409607f8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_e28a4372fd88118216d16237/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_08f00aebc7e4a729e8dcd85a/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_10dd06dabafb539d38f03207/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_eddb01bdeced73ab97c84687/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_bc7870f8d888f47f3c04dd7f/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_7785257f9a3ab9e4deba47c4/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_893ede1f09002ff3e94bfb02/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_bd4bde9ae57a57287b427725/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_9893de5c1644f5877c3e90a9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_815155ebe19736850367d69c/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_8c9a7dc88373e6144a76f8c1/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_a9a958215c3e4cb3de3f21d8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_80de012f53305f9a0940a820/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_08950d2664ed7148983dc565/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_93e77b517b4667be94abd675/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_366f9ae01c5049637d63f6f8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_ac097e02ae2ce77f15b38bf6/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_adee32f29f0f739dede254a9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_36795d6ece2290952528501b/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_29335b5ff560842227e0b995/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_633e154d52ebc2b6587c7f2e/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_c4ff77c029f06253ae74878b/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_805cb2faa8378ddf4d4452a0/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#
# All source artifacts are read-only. The notebook verifies registry hashes, schemas, record counts, builder–regime coverage, and paired question coverage before analysis.

# %% [markdown]
# ## Analysis contract
#
# The experiment is a cumulative cascade: **Native → ER → ER+RR**. The primary contrast is
# **ER+RR−Native**, the secondary contrast is **ER−Native**, and the incremental ablation is
# **ER+RR−ER**. Uncertainty is estimated by 10,000 paired, question-level bootstrap resamples
# stratified by question type (seed 42), matching the evaluated analysis contract.

# %%
from __future__ import annotations

import hashlib
import json
import math
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

start = Path.cwd().resolve()
candidates = [start, *start.parents, start / "experiment", start.parent / "experiment"]
PROJECT_ROOT = next(
    path for path in candidates
    if (path / "configs" / "experiment.yaml").is_file() and (path / "runs" / "analysis").is_dir()
)
SECTION_FOLDER = '4.7 Ablation and Error Analysis'
NOTEBOOK_DIR = PROJECT_ROOT / "analysis" / SECTION_FOLDER
OUTPUT_DIR = NOTEBOOK_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
os.environ.setdefault("MPLCONFIGDIR", str(OUTPUT_DIR / ".matplotlib"))

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from cycler import cycler
from IPython.display import Markdown, display
from matplotlib.colors import LinearSegmentedColormap, TwoSlopeNorm
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.ticker import PercentFormatter

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 100)
pd.set_option("display.float_format", lambda value: f"{value:,.4f}")

OKABE_ITO = {
    "orange": "#E69F00",
    "sky_blue": "#56B4E9",
    "bluish_green": "#009E73",
    "yellow": "#F0E442",
    "blue": "#0072B2",
    "vermillion": "#D55E00",
    "reddish_purple": "#CC79A7",
    "black": "#000000",
}
OKABE_CYCLE = [
    OKABE_ITO["blue"], OKABE_ITO["orange"], OKABE_ITO["bluish_green"],
    OKABE_ITO["vermillion"], OKABE_ITO["sky_blue"],
    OKABE_ITO["reddish_purple"], OKABE_ITO["yellow"], OKABE_ITO["black"],
]
REGIME_ORDER = ["Native", "ER", "ER+RR"]
REGIME_INTERNAL = {
    "Native": "native_lightrag",
    "ER": "advanced_lightrag_er",
    "ER+RR": "advanced_lightrag_er_rr",
}
REGIME_LABEL = {value: key for key, value in REGIME_INTERNAL.items()}
REGIME_COLORS = {
    "Native": OKABE_ITO["black"],
    "ER": OKABE_ITO["blue"],
    "ER+RR": OKABE_ITO["vermillion"],
}
FAMILY_COLORS = {
    "qwen3.5": OKABE_ITO["blue"],
    "qwen3": OKABE_ITO["orange"],
    "gemma3": OKABE_ITO["bluish_green"],
}
QUESTION_COLORS = {
    "comparison": OKABE_ITO["sky_blue"],
    "inference": OKABE_ITO["bluish_green"],
    "temporal": OKABE_ITO["orange"],
    "unanswerable": OKABE_ITO["reddish_purple"],
}
CONTRASTS = [
    ("Primary: ER+RR−Native", "Native", "ER+RR"),
    ("Secondary: ER−Native", "Native", "ER"),
    ("Incremental: ER+RR−ER", "ER", "ER+RR"),
]
CONTRAST_COLORS = {
    "Primary: ER+RR−Native": OKABE_ITO["bluish_green"],
    "Secondary: ER−Native": OKABE_ITO["sky_blue"],
    "Incremental: ER+RR−ER": OKABE_ITO["orange"],
}
CHANGE_CMAP = LinearSegmentedColormap.from_list(
    "okabe_change", [OKABE_ITO["vermillion"], "#FFFFFF", OKABE_ITO["blue"]]
)

plt.rcParams.update({
    "figure.dpi": 120,
    "savefig.dpi": 320,
    "font.family": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,
    "axes.unicode_minus": False,
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "axes.grid": True,
    "grid.alpha": 0.20,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.prop_cycle": cycler(color=OKABE_CYCLE),
})

def sha256_file(path: Path) -> str:
    digest = hashlib.sha256()
    with path.open("rb") as handle:
        for block in iter(lambda: handle.read(1024 * 1024), b""):
            digest.update(block)
    return digest.hexdigest()

def resolve_registry_path(raw_path: str) -> Path:
    path = Path(raw_path)
    if path.is_file():
        return path
    parts = path.parts
    if "runs" not in parts:
        raise FileNotFoundError(path)
    return PROJECT_ROOT / Path(*parts[parts.index("runs"):])

def read_jsonl(path: Path) -> pd.DataFrame:
    with path.open(encoding="utf-8") as handle:
        records = [json.loads(line) for line in handle if line.strip()]
    return pd.DataFrame(records)

def save_table(frame: pd.DataFrame, stem: str, index: bool = False) -> None:
    csv_path = OUTPUT_DIR / f"{stem}.csv"
    tex_path = OUTPUT_DIR / f"{stem}.tex"
    frame.to_csv(csv_path, index=index)
    latex_frame = frame.replace([np.inf, -np.inf], np.nan)
    tex_path.write_text(
        latex_frame.to_latex(index=index, float_format=lambda value: f"{value:.4f}", na_rep="—"),
        encoding="utf-8",
    )

def save_figure(fig: plt.Figure, stem: str) -> None:
    fig.savefig(OUTPUT_DIR / f"{stem}.png", dpi=320, bbox_inches="tight", facecolor="white")
    fig.savefig(OUTPUT_DIR / f"{stem}.svg", bbox_inches="tight", facecolor="white")

def stratified_mean_ci(
    frame: pd.DataFrame,
    value_col: str,
    *,
    samples: int = 10_000,
    seed: int = 42,
) -> tuple[float, float, float, int]:
    clean_frame = frame[["question_type", value_col]].dropna()
    arrays = [
        group[value_col].to_numpy(dtype=float)
        for _, group in clean_frame.groupby("question_type", sort=True)
        if len(group)
    ]
    if not arrays:
        return (np.nan, np.nan, np.nan, 0)
    observed = np.concatenate(arrays)
    rng = np.random.default_rng(seed)
    bootstrap_sum = np.zeros(samples, dtype=float)
    for values in arrays:
        indices = rng.integers(0, len(values), size=(samples, len(values)))
        bootstrap_sum += values[indices].sum(axis=1)
    bootstrap_means = bootstrap_sum / len(observed)
    lower, upper = np.quantile(bootstrap_means, [0.025, 0.975])
    return float(observed.mean()), float(lower), float(upper), int(len(observed))

def metric_question_level(metric: str, regime: str, builder: str | None = None) -> pd.DataFrame:
    subset = question_metrics.loc[
        question_metrics["graph_regime"].eq(REGIME_INTERNAL[regime]),
        ["builder_key", "question_id", "question_type", metric],
    ].dropna(subset=[metric])
    if builder is not None:
        subset = subset.loc[subset["builder_key"].eq(builder)]
    return (
        subset.groupby(["question_id", "question_type"], as_index=False, observed=True)[metric]
        .mean()
    )

def contrast_question_level(
    metric: str,
    left: str,
    right: str,
    builder: str | None = None,
) -> pd.DataFrame:
    subset = question_metrics[
        ["builder_key", "question_id", "question_type", "graph_regime", metric]
    ].dropna(subset=[metric])
    if builder is not None:
        subset = subset.loc[subset["builder_key"].eq(builder)]
    wide = subset.pivot_table(
        index=["builder_key", "question_id", "question_type"],
        columns="graph_regime",
        values=metric,
        aggfunc="mean",
    )
    left_key, right_key = REGIME_INTERNAL[left], REGIME_INTERNAL[right]
    paired = wide.dropna(subset=[left_key, right_key]).copy()
    paired["difference"] = paired[right_key] - paired[left_key]
    return (
        paired.reset_index()
        .groupby(["question_id", "question_type"], as_index=False, observed=True)["difference"]
        .mean()
    )

def overall_metric_estimate(metric: str, regime: str) -> dict:
    frame = metric_question_level(metric, regime)
    mean, lower, upper, count = stratified_mean_ci(frame, metric)
    return {
        "metric": metric, "regime": regime, "mean": mean,
        "ci_lower": lower, "ci_upper": upper, "question_count": count,
    }

def contrast_metric_estimate(
    metric: str,
    contrast: str,
    left: str,
    right: str,
    builder: str | None = None,
    seed: int = 42,
) -> dict:
    frame = contrast_question_level(metric, left, right, builder)
    mean, lower, upper, count = stratified_mean_ci(
        frame, "difference", seed=seed
    )
    left_frame = metric_question_level(metric, left, builder)
    left_mean = left_frame[metric].mean()
    relative = 100 * mean / left_mean if pd.notna(left_mean) and left_mean != 0 else np.nan
    return {
        "builder_key": builder,
        "contrast": contrast,
        "metric": metric,
        "left_regime": left,
        "right_regime": right,
        "left_mean": left_mean,
        "mean_difference": mean,
        "ci_lower": lower,
        "ci_upper": upper,
        "relative_difference_percent": relative,
        "paired_question_count": count,
    }

print(f"Project root: {PROJECT_ROOT}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Project root: .
# Output directory: analysis/4.7 Ablation and Error Analysis/output

# %% [markdown]
# ## Load and validate the evaluated data
#
# The active input registry in the global report is authoritative. This avoids accidentally
# including historical variants while still checking every file against its recorded hash,
# schema, row count, regime, and paired coverage.

# %%
GLOBAL_REPORT_PATH = PROJECT_ROOT / "runs" / "analysis" / "global_experiment_report.34d2c998f8e8143d.json"
global_report = json.loads(GLOBAL_REPORT_PATH.read_text(encoding="utf-8"))
assert global_report["schema_version"] == "2.0.0"
assert global_report["builder_count"] == 12
assert global_report["expected_question_count"] == 120
assert global_report["graph_regimes"] == list(REGIME_LABEL)
assert global_report["bootstrap"] == {
    "cluster_unit": "question_id",
    "confidence_level": 0.95,
    "method": "paired_stratified_percentile_by_question_type",
    "samples": 10000,
    "seed": 42,
    "shared_resample_plan": True,
}

builder_meta = pd.DataFrame([
    {
        "builder_key": row["builder_key"],
        "display_name": row["display_name"],
        "family": row["family"],
        "parameter_billions": row["parameter_billions"],
        "scale_band": row["scale_band"],
    }
    for row in global_report["family_and_scale"]["builder_metrics"]
])
builder_order = builder_meta["builder_key"].tolist()
display_order = builder_meta["display_name"].tolist()
builder_lookup = builder_meta.set_index("builder_key").to_dict("index")

metric_entries = []
for logical_name, metadata in global_report["input_artifacts"].items():
    parts = logical_name.split("/")
    if len(parts) == 2 and parts[1] in REGIME_LABEL:
        metric_entries.append((parts[0], parts[1], metadata))
metric_entries.sort(key=lambda item: (builder_order.index(item[0]), list(REGIME_LABEL).index(item[1])))
assert len(metric_entries) == 36

frames = []
validation_rows = []
required_columns = {
    "question_id", "question_type", "graph_regime", "builder_model",
    "retrieval_hit", "retrieval_recall", "reciprocal_rank",
    "answer_correct", "token_f1", "retrieval_latency_ms",
    "answer_latency_ms", "context_token_count", "answer_total_tokens",
}
for builder_key, regime, metadata in metric_entries:
    path = resolve_registry_path(metadata["path"])
    frame = read_jsonl(path)
    missing = required_columns.difference(frame.columns)
    if missing:
        raise ValueError(f"{path} is missing required fields: {sorted(missing)}")
    actual_hash = sha256_file(path)
    valid = (
        actual_hash == metadata["sha256"]
        and len(frame) == metadata["record_count"] == 120
        and set(frame["schema_version"]) == {metadata["schema_version"]} == {"3.0.0"}
        and set(frame["graph_regime"]) == {regime}
    )
    if not valid:
        raise ValueError(f"Artifact validation failed: {path}")
    frame["builder_key"] = builder_key
    frames.append(frame)
    validation_rows.append({
        "builder_key": builder_key,
        "regime": REGIME_LABEL[regime],
        "relative_path": path.relative_to(PROJECT_ROOT).as_posix(),
        "records": len(frame),
        "schema_version": metadata["schema_version"],
        "sha256_verified": actual_hash == metadata["sha256"],
    })

question_metrics = pd.concat(frames, ignore_index=True)
question_metrics = question_metrics.merge(builder_meta, on="builder_key", how="left", validate="many_to_one")
question_metrics["regime"] = question_metrics["graph_regime"].map(REGIME_LABEL)
question_metrics["regime"] = pd.Categorical(
    question_metrics["regime"], categories=REGIME_ORDER, ordered=True
)
question_metrics["builder_key"] = pd.Categorical(
    question_metrics["builder_key"], categories=builder_order, ordered=True
)
source_validation = pd.DataFrame(validation_rows)

coverage = (
    question_metrics.groupby(["builder_key", "regime"], observed=True)["question_id"]
    .nunique().unstack()
)
if question_metrics.shape[0] != 4_320 or not coverage.eq(120).all().all():
    raise ValueError(f"Unexpected evaluated coverage: rows={len(question_metrics)}")
if question_metrics[["builder_key", "regime", "question_id"]].duplicated().any():
    raise ValueError("Duplicate builder–regime–question rows detected")

save_table(source_validation, "source_validation")
display(source_validation)
print(f"Validated {len(source_validation)} source files and {len(question_metrics):,} evaluated rows.")
print(f"Question types: {question_metrics['question_type'].value_counts().to_dict()}")
# Out:
#     builder_key  regime  \
# 0   qwen35_0_8b  Native
# 1   qwen35_0_8b      ER
# 2   qwen35_0_8b   ER+RR
# 3     qwen35_2b  Native
# 4     qwen35_2b      ER
# 5     qwen35_2b   ER+RR
# 6     qwen35_4b  Native
# 7     qwen35_4b      ER
# 8     qwen35_4b   ER+RR
# 9     qwen35_9b  Native
# 10    qwen35_9b      ER
# 11    qwen35_9b   ER+RR
# 12   qwen3_0_6b  Native
# 13   qwen3_0_6b      ER
# 14   qwen3_0_6b   ER+RR
# 15   qwen3_1_7b  Native
# 16   qwen3_1_7b      ER
# 17   qwen3_1_7b   ER+RR
# 18     qwen3_4b  Native
# 19     qwen3_4b      ER
# 20     qwen3_4b   ER+RR
# 21     qwen3_8b  Native
# 22     qwen3_8b      ER
# 23     qwen3_8b   ER+RR
# 24  gemma3_270m  Native
# 25  gemma3_270m      ER
# 26  gemma3_270m   ER+RR
# 27    gemma3_1b  Native
# 28    gemma3_1b      ER
# 29    gemma3_1b   ER+RR
# 30    gemma3_4b  Native
# 31    gemma3_4b      ER
# 32    gemma3_4b   ER+RR
# 33   gemma3_12b  Native
# 34   gemma3_12b      ER
# 35   gemma3_12b   ER+RR
#
#                                                                                           relative_path  \
# 0   runs/variants/variant_native_08f00aebc7e4a729e8dcd85a/metrics/question_metrics.904bfaacde8e272e....
# 1     runs/variants/variant_er_a622307fd50890d7409607f8/metrics/question_metrics.904bfaacde8e272e.jsonl
# 2     runs/variants/variant_rr_e28a4372fd88118216d16237/metrics/question_metrics.904bfaacde8e272e.jsonl
# 3   runs/variants/variant_native_bc7870f8d888f47f3c04dd7f/metrics/question_metrics.904bfaacde8e272e....
# 4     runs/variants/variant_er_10dd06dabafb539d38f03207/metrics/question_metrics.904bfaacde8e272e.jsonl
# 5     runs/variants/variant_rr_eddb01bdeced73ab97c84687/metrics/question_metrics.904bfaacde8e272e.jsonl
# 6   runs/variants/variant_native_bd4bde9ae57a57287b427725/metrics/question_metrics.904bfaacde8e272e....
# 7     runs/variants/variant_er_7785257f9a3ab9e4deba47c4/metrics/question_metrics.904bfaacde8e272e.jsonl
# 8     runs/variants/variant_rr_893ede1f09002ff3e94bfb02/metrics/question_metrics.904bfaacde8e272e.jsonl
# 9   runs/variants/variant_native_8c9a7dc88373e6144a76f8c1/metrics/question_metrics.904bfaacde8e272e....
# 10    runs/variants/variant_er_9893de5c1644f5877c3e90a9/metrics/question_metrics.904bfaacde8e272e.jsonl
# 11    runs/variants/variant_rr_815155ebe19736850367d69c/metrics/question_metrics.904bfaacde8e272e.jsonl
# 12  runs/variants/variant_native_08950d2664ed7148983dc565/metrics/question_metrics.904bfaacde8e272e....
# 13    runs/variants/variant_er_a9a958215c3e4cb3de3f21d8/metrics/question_metrics.904bfaacde8e272e.jsonl
# 14    runs/variants/variant_rr_80de012f53305f9a0940a820/metrics/question_metrics.904bfaacde8e272e.jsonl
# 15  runs/variants/variant_native_ac097e02ae2ce77f15b38bf6/metrics/question_metrics.904bfaacde8e272e....
# 16    runs/variants/variant_er_93e77b517b4667be94abd675/metrics/question_metrics.904bfaacde8e272e.jsonl
# 17    runs/variants/variant_rr_366f9ae01c5049637d63f6f8/metrics/question_metrics.904bfaacde8e272e.jsonl
# 18  runs/variants/variant_native_29335b5ff560842227e0b995/metrics/question_metrics.904bfaacde8e272e....
# 19    runs/variants/variant_er_adee32f29f0f739dede254a9/metrics/question_metrics.904bfaacde8e272e.jsonl
# 20    runs/variants/variant_rr_36795d6ece2290952528501b/metrics/question_metrics.904bfaacde8e272e.jsonl
# 21  runs/variants/variant_native_805cb2faa8378ddf4d4452a0/metrics/question_metrics.904bfaacde8e272e....
# 22    runs/variants/variant_er_633e154d52ebc2b6587c7f2e/metrics/question_metrics.904bfaacde8e272e.jsonl
# 23    runs/variants/variant_rr_c4ff77c029f06253ae74878b/metrics/question_metrics.904bfaacde8e272e.jsonl
# 24  runs/variants/variant_native_2b68fc1e293f9a495f3b40ab/metrics/question_metrics.904bfaacde8e272e....
# 25    runs/variants/variant_er_8487befcdc34573a74986444/metrics/question_metrics.904bfaacde8e272e.jsonl
# 26    runs/variants/variant_rr_9978ad4c0e3c4eab0acc8705/metrics/question_metrics.904bfaacde8e272e.jsonl
# 27  runs/variants/variant_native_4c7fe3e91e1ce688febabbe1/metrics/question_metrics.904bfaacde8e272e....
# 28    runs/variants/variant_er_28508ddd03bad1b453b1ac27/metrics/question_metrics.904bfaacde8e272e.jsonl
# 29    runs/variants/variant_rr_f6886e1fcfead6531b3c7850/metrics/question_metrics.904bfaacde8e272e.jsonl
# 30  runs/variants/variant_native_ed7fe257a2a5d1ca497b9531/metrics/question_metrics.904bfaacde8e272e....
# 31    runs/variants/variant_er_6756da7bf5b8ad0e2566fbe9/metrics/question_metrics.904bfaacde8e272e.jsonl
# 32    runs/variants/variant_rr_c81e35865e785a11de06d57a/metrics/question_metrics.904bfaacde8e272e.jsonl
# 33  runs/variants/variant_native_c41e9c339aaefbc613be1a13/metrics/question_metrics.904bfaacde8e272e....
# 34    runs/variants/variant_er_2b1eb0de0420e8a59f0008ff/metrics/question_metrics.904bfaacde8e272e.jsonl
# 35    runs/variants/variant_rr_fa60813adc48b7946504cad9/metrics/question_metrics.904bfaacde8e272e.jsonl
#
#     records schema_version  sha256_verified
# 0       120          3.0.0             True
# 1       120          3.0.0             True
# 2       120          3.0.0             True
# 3       120          3.0.0             True
# 4       120          3.0.0             True
# 5       120          3.0.0             True
# 6       120          3.0.0             True
# 7       120          3.0.0             True
# 8       120          3.0.0             True
# 9       120          3.0.0             True
# 10      120          3.0.0             True
# 11      120          3.0.0             True
# 12      120          3.0.0             True
# 13      120          3.0.0             True
# 14      120          3.0.0             True
# 15      120          3.0.0             True
# 16      120          3.0.0             True
# 17      120          3.0.0             True
# 18      120          3.0.0             True
# 19      120          3.0.0             True
# 20      120          3.0.0             True
# 21      120          3.0.0             True
# 22      120          3.0.0             True
# 23      120          3.0.0             True
# 24      120          3.0.0             True
# 25      120          3.0.0             True
# 26      120          3.0.0             True
# 27      120          3.0.0             True
# 28      120          3.0.0             True
# 29      120          3.0.0             True
# 30      120          3.0.0             True
# 31      120          3.0.0             True
# 32      120          3.0.0             True
# 33      120          3.0.0             True
# 34      120          3.0.0             True
# 35      120          3.0.0             True
# Validated 36 source files and 4,320 evaluated rows.
# Question types: {'comparison': 1080, 'unanswerable': 1080, 'temporal': 1080, 'inference': 1080}

# %% [markdown]
# ## Incremental RR ablation
#
# The central estimand is ER+RR−ER, which isolates RR conditional on ER. Builder-level bootstrap intervals expose
# heterogeneous effects; a null mean ablation is not treated as an experiment failure.

# %%
PRIMARY_PATH = PROJECT_ROOT / "runs" / "analysis" / "prespecified_cascade_comparisons.6869b0d1a39bd730.json"
primary_report = json.loads(PRIMARY_PATH.read_text(encoding="utf-8"))
assert primary_report["schema_version"] == "2.0.0"
assert primary_report["total_prespecified_comparison_count"] == 36

ABLATION_METRICS = {
    "retrieval_hit": "Retrieval hit",
    "retrieval_recall": "Gold-document recall",
    "reciprocal_rank": "MRR",
    "answer_correct": "Answer correctness",
    "token_f1": "Token F1",
}
rr_effects = pd.DataFrame([
    contrast_metric_estimate(
        metric, "Incremental: ER+RR−ER", "ER", "ER+RR",
        builder=builder, seed=242 + builder_order.index(builder),
    )
    for builder in builder_order
    for metric in ABLATION_METRICS
]).merge(builder_meta, on="builder_key", how="left")
rr_overall = pd.DataFrame([
    contrast_metric_estimate(
        metric, "Incremental: ER+RR−ER", "ER", "ER+RR"
    )
    for metric in ABLATION_METRICS
])
save_table(rr_effects, "incremental_rr_effects_by_builder")
save_table(rr_overall, "incremental_rr_effects_overall")
display(rr_overall)
# Out:
#   builder_key               contrast            metric left_regime  \
# 0        None  Incremental: ER+RR−ER     retrieval_hit          ER
# 1        None  Incremental: ER+RR−ER  retrieval_recall          ER
# 2        None  Incremental: ER+RR−ER   reciprocal_rank          ER
# 3        None  Incremental: ER+RR−ER    answer_correct          ER
# 4        None  Incremental: ER+RR−ER          token_f1          ER
#
#   right_regime  left_mean  mean_difference  ci_lower  ci_upper  \
# 0        ER+RR     0.3843           0.0028   -0.0056    0.0120
# 1        ER+RR     0.1734           0.0034   -0.0014    0.0084
# 2        ER+RR     0.3333          -0.0018   -0.0069    0.0031
# 3        ER+RR     0.3215          -0.0014   -0.0118    0.0097
# 4        ER+RR     0.1888          -0.0054   -0.0158    0.0057
#
#    relative_difference_percent  paired_question_count
# 0                       0.7229                     90
# 1                       1.9582                     90
# 2                      -0.5464                     90
# 3                      -0.4320                    120
# 4                      -2.8452                     90

# %% [markdown]
# ## Exact paired discordance tests
#
# Exact two-sided McNemar tests compare binary retrieval-hit and answer-correctness outcomes on identical questions.
# Holm adjustment is applied separately across the 12 builders for each metric.

# %%
def exact_binomial_two_sided(successes: int, trials: int) -> float:
    if trials == 0:
        return 1.0
    tail = sum(math.comb(trials, k) for k in range(0, min(successes, trials - successes) + 1)) / (2 ** trials)
    return min(1.0, 2 * tail)

def holm_adjust(p_values):
    values = np.asarray(p_values, dtype=float)
    order = np.argsort(values)
    adjusted = np.empty_like(values)
    running = 0.0
    total = len(values)
    for rank, index in enumerate(order):
        running = max(running, (total - rank) * values[index])
        adjusted[index] = min(1.0, running)
    return adjusted

mcnemar_rows = []
for metric in ["retrieval_hit", "answer_correct"]:
    for builder in builder_order:
        subset = question_metrics.loc[
            question_metrics["builder_key"].astype(str).eq(builder),
            ["question_id", "graph_regime", metric],
        ].dropna(subset=[metric])
        wide = subset.pivot(index="question_id", columns="graph_regime", values=metric).dropna(
            subset=[REGIME_INTERNAL["ER"], REGIME_INTERNAL["ER+RR"]]
        )
        er = wide[REGIME_INTERNAL["ER"]].astype(bool)
        rr = wide[REGIME_INTERNAL["ER+RR"]].astype(bool)
        er_only = int((er & ~rr).sum())
        rr_only = int((~er & rr).sum())
        discordant = er_only + rr_only
        mcnemar_rows.append({
            "builder_key": builder,
            "metric": metric,
            "er_only_success": er_only,
            "rr_only_success": rr_only,
            "discordant_pairs": discordant,
            "raw_p_value": exact_binomial_two_sided(rr_only, discordant),
            "paired_questions": len(wide),
        })
mcnemar_results = pd.DataFrame(mcnemar_rows)
mcnemar_results["holm_adjusted_p_value"] = (
    mcnemar_results.groupby("metric")["raw_p_value"].transform(holm_adjust)
)
mcnemar_results["holm_reject_0_05"] = mcnemar_results["holm_adjusted_p_value"] < 0.05
mcnemar_results = mcnemar_results.merge(builder_meta, on="builder_key", how="left")
save_table(mcnemar_results, "rr_mcnemar_by_builder")
display(mcnemar_results)
# Out:
#     builder_key          metric  er_only_success  rr_only_success  \
# 0   qwen35_0_8b   retrieval_hit                4                0
# 1     qwen35_2b   retrieval_hit                0                1
# 2     qwen35_4b   retrieval_hit                0                0
# 3     qwen35_9b   retrieval_hit                1                2
# 4    qwen3_0_6b   retrieval_hit                0                0
# 5    qwen3_1_7b   retrieval_hit                0                0
# 6      qwen3_4b   retrieval_hit                1                0
# 7      qwen3_8b   retrieval_hit                0                2
# 8   gemma3_270m   retrieval_hit                2                6
# 9     gemma3_1b   retrieval_hit                1                0
# 10    gemma3_4b   retrieval_hit                0                0
# 11   gemma3_12b   retrieval_hit                0                1
# 12  qwen35_0_8b  answer_correct                7                1
# 13    qwen35_2b  answer_correct                3                0
# 14    qwen35_4b  answer_correct                1                2
# 15    qwen35_9b  answer_correct                2                0
# 16   qwen3_0_6b  answer_correct                1                3
# 17   qwen3_1_7b  answer_correct                1                2
# 18     qwen3_4b  answer_correct                1                1
# 19     qwen3_8b  answer_correct                3                3
# 20  gemma3_270m  answer_correct                2                4
# 21    gemma3_1b  answer_correct                3                3
# 22    gemma3_4b  answer_correct                1                3
# 23   gemma3_12b  answer_correct                0                1
#
#     discordant_pairs  raw_p_value  paired_questions  holm_adjusted_p_value  \
# 0                  4       0.1250                90                 1.0000
# 1                  1       1.0000                90                 1.0000
# 2                  0       1.0000                90                 1.0000
# 3                  3       1.0000                90                 1.0000
# 4                  0       1.0000                90                 1.0000
# 5                  0       1.0000                90                 1.0000
# 6                  1       1.0000                90                 1.0000
# 7                  2       0.5000                90                 1.0000
# 8                  8       0.2891                90                 1.0000
# 9                  1       1.0000                90                 1.0000
# 10                 0       1.0000                90                 1.0000
# 11                 1       1.0000                90                 1.0000
# 12                 8       0.0703               120                 0.8438
# 13                 3       0.2500               120                 1.0000
# 14                 3       1.0000               120                 1.0000
# 15                 2       0.5000               120                 1.0000
# 16                 4       0.6250               120                 1.0000
# 17                 3       1.0000               120                 1.0000
# 18                 2       1.0000               120                 1.0000
# 19                 6       1.0000               120                 1.0000
# 20                 6       0.6875               120                 1.0000
# 21                 6       1.0000               120                 1.0000
# 22                 4       0.6250               120                 1.0000
# 23                 1       1.0000               120                 1.0000
#
#     holm_reject_0_05  display_name   family  parameter_billions scale_band
# 0              False  Qwen3.5 0.8B  qwen3.5              0.8000     sub_1b
# 1              False    Qwen3.5 2B  qwen3.5              2.0000  1_to_lt4b
# 2              False    Qwen3.5 4B  qwen3.5              4.0000  4_to_lt8b
# 3              False    Qwen3.5 9B  qwen3.5              9.0000    8b_plus
# 4              False    Qwen3 0.6B    qwen3              0.6000     sub_1b
# 5              False    Qwen3 1.7B    qwen3              1.7000  1_to_lt4b
# 6              False      Qwen3 4B    qwen3              4.0000  4_to_lt8b
# 7              False      Qwen3 8B    qwen3              8.0000    8b_plus
# 8              False  Gemma 3 270M   gemma3              0.2700     sub_1b
# 9              False    Gemma 3 1B   gemma3              1.0000  1_to_lt4b
# 10             False    Gemma 3 4B   gemma3              4.0000  4_to_lt8b
# 11             False   Gemma 3 12B   gemma3             12.0000    8b_plus
# 12             False  Qwen3.5 0.8B  qwen3.5              0.8000     sub_1b
# 13             False    Qwen3.5 2B  qwen3.5              2.0000  1_to_lt4b
# 14             False    Qwen3.5 4B  qwen3.5              4.0000  4_to_lt8b
# 15             False    Qwen3.5 9B  qwen3.5              9.0000    8b_plus
# 16             False    Qwen3 0.6B    qwen3              0.6000     sub_1b
# 17             False    Qwen3 1.7B    qwen3              1.7000  1_to_lt4b
# 18             False      Qwen3 4B    qwen3              4.0000  4_to_lt8b
# 19             False      Qwen3 8B    qwen3              8.0000    8b_plus
# 20             False  Gemma 3 270M   gemma3              0.2700     sub_1b
# 21             False    Gemma 3 1B   gemma3              1.0000  1_to_lt4b
# 22             False    Gemma 3 4B   gemma3              4.0000  4_to_lt8b
# 23             False   Gemma 3 12B   gemma3             12.0000    8b_plus

# %% [markdown]
# ## Error taxonomy and recurrent difficult questions
#
# The taxonomy first distinguishes technical failures, then retrieval misses, correct answers, over-abstention,
# hallucination, and other answer errors. Recurrent difficulty is measured across all builder–regime cells and joined
# to the curated question text for transparent qualitative follow-up.

# %%
def classify_outcome(row):
    is_true = lambda value: pd.notna(value) and bool(value)
    if is_true(row.get("retrieval_failed")) or is_true(row.get("retrieval_empty")):
        return "Retrieval failure or empty context"
    if is_true(row.get("answer_failed")):
        return "Answer-generation failure"
    if is_true(row.get("answerable")):
        if not is_true(row.get("retrieval_hit")):
            return "Retrieval miss"
        if is_true(row.get("answer_correct")):
            return "Correct answer"
        if is_true(row.get("over_abstention")):
            return "Over-abstention despite retrieval hit"
        if is_true(row.get("hallucination")):
            return "Hallucination after retrieval hit"
        return "Evidence retrieved, answer incorrect"
    if is_true(row.get("unanswerable_correct")):
        return "Correct unanswerable decision"
    return "Incorrect unanswerable decision"

error_frame = question_metrics.copy()
error_frame["outcome_group"] = error_frame.apply(classify_outcome, axis=1)
error_summary = (
    error_frame.groupby(["regime", "question_type", "outcome_group"], observed=True)
    .size().rename("count").reset_index()
)
error_summary["share_within_stratum"] = (
    error_summary["count"] /
    error_summary.groupby(["regime", "question_type"])["count"].transform("sum")
)

QUESTIONS_PATH = PROJECT_ROOT / "multihoprag_120" / "questions.jsonl"
questions = read_jsonl(QUESTIONS_PATH)
if len(questions) != 120 or questions["question_id"].nunique() != 120:
    raise ValueError("Question registry is incomplete")
error_frame["is_error"] = np.where(
    error_frame["answerable"].eq(True),
    ~error_frame["answer_correct"].fillna(False).astype(bool),
    ~error_frame["unanswerable_correct"].fillna(False).astype(bool),
)
hard_questions = (
    error_frame.groupby(["question_id", "question_type"], observed=True)
    .agg(
        error_rate=("is_error", "mean"),
        retrieval_miss_rate=("retrieval_hit", lambda values: 1 - values.dropna().mean() if values.notna().any() else np.nan),
        over_abstention_rate=("over_abstention", "mean"),
        evaluated_cells=("is_error", "size"),
    )
    .reset_index()
    .merge(questions[["question_id", "question", "gold_answer", "answerable"]], on="question_id", how="left", validate="one_to_one")
    .sort_values(["error_rate", "retrieval_miss_rate"], ascending=False)
)
save_table(error_summary, "error_taxonomy_by_regime_and_question_type")
save_table(hard_questions, "recurrent_difficult_questions")
display(hard_questions.head(15))
# Out:
#               question_id question_type  error_rate  retrieval_miss_rate  \
# 69   mhq_8c07cbf7661890fd    comparison      1.0000               1.0000
# 83   mhq_b75d6e5f4903d90a    comparison      1.0000               1.0000
# 90   mhq_bea6a666f86823f2     inference      1.0000               1.0000
# 74   mhq_9976c73601143ab0      temporal      1.0000               0.9722
# 86   mhq_bab967ae9e11c83b    comparison      1.0000               0.9722
# 56   mhq_7f7866c6c0a3afc3      temporal      1.0000               0.9444
# 103  mhq_dbb1ef0bb5d9b196    comparison      1.0000               0.9444
# 110  mhq_ee1edaefc29d0fce    comparison      1.0000               0.9444
# 89   mhq_be47910112b694cd      temporal      1.0000               0.9167
# 106  mhq_e689c58ff123d56d      temporal      1.0000               0.9167
# 28   mhq_3e8219f583173d97    comparison      1.0000               0.8889
# 30   mhq_4083498e9e104f97      temporal      1.0000               0.8889
# 55   mhq_7e6e955d60ce6593      temporal      1.0000               0.8889
# 105  mhq_e3cbe83c410a2434     inference      1.0000               0.8889
# 49   mhq_7277ec2b9f00ee5f    comparison      1.0000               0.8611
#
#     over_abstention_rate  evaluated_cells  \
# 69                0.6944               36
# 83                0.9722               36
# 90                0.8889               36
# 74                1.0000               36
# 86                0.9722               36
# 56                1.0000               36
# 103               1.0000               36
# 110               1.0000               36
# 89                1.0000               36
# 106               0.9722               36
# 28                0.9722               36
# 30                0.9722               36
# 55                1.0000               36
# 105               0.6389               36
# 49                0.6667               36
#
#                                                                                                 question  \
# 69   Does 'The Age' suggest that the co-founders of Anthropic made no attempt to remove Sam Altman fr...
# 83   Does the article from 'The Age' suggest that 'The individual's dating intentions' were not focus...
# 90   Which company, covered by TechCrunch, The Verge, and Fortune, had its largest assets in "unlocke...
# 74   Has the advice provided by Sporting News to bettors regarding the evaluation of betting opportun...
# 86   Does 'The Guardian' article suggest a different level of performance for Tyreek Hill in a specif...
# 56   Between the report from Fortune published on October 4, 2023, and the report from TechCrunch, wa...
# 103  Does 'The New York Times' article suggest that Chelsea Football Club's expansion in the U.S. mar...
# 110  Did the TechCrunch article on software companies report a decrease in revenue related to payment...
# 89   Was there inconsistency in the TechCrunch reports on Google's engagement in anticompetitive beha...
# 106  After The Verge reported on September 26, 2023, that Apple defended its Google Search deal by st...
# 28   Does the Polygon article suggest that "Video games in 2023" have undergone a significant change ...
# 30   Did the Sporting News fail to report on Elijah Garcia's 16th victory before The Roar | Sports Wr...
# 55   Between the Sporting News report on Kenneth Walker III's injury impact for fantasy football publ...
# 105  Which football club, recently discussed in articles from 'The Guardian', 'The Roar | Sports Writ...
# 49   Does the 'Fortune' article claim that Sam Bankman-Fried used Caroline Ellison as a front for mis...
#
#                gold_answer  answerable
# 69                    True        True
# 83                      no        True
# 90        Alameda Research        True
# 74                      no        True
# 86                     Yes        True
# 56                     Yes        True
# 103                     no        True
# 110                     no        True
# 89                      no        True
# 106                    Yes        True
# 28                     Yes        True
# 30                      no        True
# 55                      no        True
# 105  Everton Football Club        True
# 49                     Yes        True

# %% [markdown]
# ## ER → ER+RR outcome transitions
#
# Transition tables count improvements, regressions, and stable outcomes on identical builder–question pairs.
# They complement mean effects by showing whether a small average masks many offsetting changes.

# %%
transition_rows = []
for metric in ["retrieval_hit", "answer_correct"]:
    subset = question_metrics[["builder_key", "question_id", "question_type", "graph_regime", metric]].dropna(subset=[metric])
    wide = subset.pivot_table(
        index=["builder_key", "question_id", "question_type"],
        columns="graph_regime", values=metric, aggfunc="mean",
    ).dropna(subset=[REGIME_INTERNAL["ER"], REGIME_INTERNAL["ER+RR"]])
    er_values = wide[REGIME_INTERNAL["ER"]].astype(bool)
    rr_values = wide[REGIME_INTERNAL["ER+RR"]].astype(bool)
    states = pd.DataFrame({
        "builder_key": wide.index.get_level_values("builder_key").astype(str),
        "question_id": wide.index.get_level_values("question_id"),
        "question_type": wide.index.get_level_values("question_type"),
        "er_success": er_values.to_numpy(),
        "er_rr_success": rr_values.to_numpy(),
    })
    grouped = (
        states.groupby(["question_type", "er_success", "er_rr_success"], observed=True)
        .size().rename("count").reset_index()
    )
    grouped["metric"] = metric
    transition_rows.append(grouped)
transitions = pd.concat(transition_rows, ignore_index=True)
save_table(transitions, "er_to_er_rr_outcome_transitions")

qtype_rr_effects = (
    question_metrics.loc[question_metrics["regime"].isin(["ER", "ER+RR"])]
    .groupby(["question_type", "regime"], observed=True)
    .agg(
        retrieval_hit=("retrieval_hit", "mean"),
        retrieval_recall=("retrieval_recall", "mean"),
        answer_correct=("answer_correct", "mean"),
        token_f1=("token_f1", "mean"),
    )
    .reset_index()
    .pivot(index="question_type", columns="regime")
)
qtype_effect_rows = []
for question_type in qtype_rr_effects.index:
    for metric in ["retrieval_hit", "retrieval_recall", "answer_correct", "token_f1"]:
        qtype_effect_rows.append({
            "question_type": question_type,
            "metric": metric,
            "er_mean": qtype_rr_effects.loc[question_type, (metric, "ER")],
            "er_rr_mean": qtype_rr_effects.loc[question_type, (metric, "ER+RR")],
            "incremental_difference": (
                qtype_rr_effects.loc[question_type, (metric, "ER+RR")]
                - qtype_rr_effects.loc[question_type, (metric, "ER")]
            ),
        })
qtype_rr_effects_long = pd.DataFrame(qtype_effect_rows)
save_table(qtype_rr_effects_long, "rr_effects_by_question_type")
display(qtype_rr_effects_long)
# Out:
#    question_type            metric  er_mean  er_rr_mean  \
# 0     comparison     retrieval_hit   0.3861      0.3861
# 1     comparison  retrieval_recall   0.1940      0.2009
# 2     comparison    answer_correct   0.0611      0.0528
# 3     comparison          token_f1   0.0611      0.0528
# 4      inference     retrieval_hit   0.3611      0.3667
# 5      inference  retrieval_recall   0.1363      0.1377
# 6      inference    answer_correct   0.4111      0.4000
# 7      inference          token_f1   0.4496      0.4390
# 8       temporal     retrieval_hit   0.4056      0.4083
# 9       temporal  retrieval_recall   0.1898      0.1917
# 10      temporal    answer_correct   0.0556      0.0583
# 11      temporal          token_f1   0.0558      0.0585
# 12  unanswerable     retrieval_hit      NaN         NaN
# 13  unanswerable  retrieval_recall      NaN         NaN
# 14  unanswerable    answer_correct   0.7583      0.7694
# 15  unanswerable          token_f1      NaN         NaN
#
#     incremental_difference
# 0                   0.0000
# 1                   0.0069
# 2                  -0.0083
# 3                  -0.0083
# 4                   0.0056
# 5                   0.0014
# 6                  -0.0111
# 7                  -0.0106
# 8                   0.0028
# 9                   0.0019
# 10                  0.0028
# 11                  0.0028
# 12                     NaN
# 13                     NaN
# 14                  0.0111
# 15                     NaN

# %% [markdown]
# ## Figure 4.7.1 — Builder-level RR ablation effects
#
# Points and 95% intervals show ER+RR−ER. The zero line marks no incremental RR contribution; mixed signs indicate
# heterogeneity rather than a stable population-wide benefit.

# %%
plot_metrics = ["retrieval_hit", "retrieval_recall", "answer_correct", "token_f1"]
fig, axes = plt.subplots(2, 2, figsize=(14.5, 10), constrained_layout=True)
y = np.arange(len(display_order))
for ax, metric in zip(axes.flat, plot_metrics):
    subset = rr_effects.loc[rr_effects["metric"].eq(metric)].set_index("display_name").reindex(display_order)
    means = subset["mean_difference"].to_numpy() * 100
    lower = subset["ci_lower"].to_numpy() * 100
    upper = subset["ci_upper"].to_numpy() * 100
    colors = [FAMILY_COLORS[builder_lookup[key]["family"]] for key in builder_order]
    ax.errorbar(means, y, xerr=np.vstack([means - lower, upper - means]), fmt="none", ecolor="#777777", capsize=3, linewidth=1)
    ax.scatter(means, y, color=colors, s=48, zorder=3)
    ax.axvline(0, color=OKABE_ITO["black"], linewidth=1)
    ax.set_yticks(y, display_order)
    ax.invert_yaxis()
    ax.set_xlabel(f"{ABLATION_METRICS[metric]} change (percentage points)")
    ax.grid(axis="y", alpha=0.12)
save_figure(fig, "01_incremental_rr_effect_forest")
plt.show()

# %% [markdown]
# ## Figure 4.7.2 — Overall ER→ER+RR transition matrices
#
# Off-diagonal cells distinguish improvements from regressions. Balanced off-diagonal counts explain why a mean
# ablation can be close to zero even when RR changes many individual outcomes.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10.5, 4.8), constrained_layout=True)
for ax, metric in zip(axes, ["retrieval_hit", "answer_correct"]):
    subset = transitions.loc[transitions["metric"].eq(metric)]
    matrix = np.zeros((2, 2), dtype=int)
    for row in subset.itertuples():
        matrix[int(row.er_success), int(row.er_rr_success)] += int(row.count)
    image = ax.imshow(matrix, cmap="Blues")
    ax.set_xticks([0, 1], ["Failure", "Success"])
    ax.set_yticks([0, 1], ["Failure", "Success"])
    ax.set_xlabel("ER+RR outcome")
    ax.set_ylabel("ER outcome")
    ax.set_title(ABLATION_METRICS[metric])
    for row in range(2):
        for column in range(2):
            ax.text(column, row, f"{matrix[row, column]:,}", ha="center", va="center", color="white" if matrix[row, column] > matrix.max() / 2 else "black")
save_figure(fig, "02_er_to_er_rr_transition_matrices")
plt.show()

# %% [markdown]
# ## Figure 4.7.3 — Error composition by regime
#
# The stacked distribution shows whether post-processing changes the dominant bottleneck from missing evidence to
# generation failures, abstention, or hallucination.

# %%
outcome_order = [
    "Correct answer", "Correct unanswerable decision", "Retrieval miss",
    "Over-abstention despite retrieval hit", "Hallucination after retrieval hit",
    "Evidence retrieved, answer incorrect", "Incorrect unanswerable decision",
    "Retrieval failure or empty context", "Answer-generation failure",
]
outcome_colors = [
    OKABE_ITO["bluish_green"], OKABE_ITO["blue"], OKABE_ITO["orange"],
    OKABE_ITO["sky_blue"], OKABE_ITO["vermillion"], OKABE_ITO["yellow"],
    OKABE_ITO["reddish_purple"], "#777777", "#BBBBBB",
]
overall_errors = (
    error_frame.groupby(["regime", "outcome_group"], observed=True)
    .size().rename("count").reset_index()
)
overall_errors["share"] = overall_errors["count"] / overall_errors.groupby("regime")["count"].transform("sum")
pivot = overall_errors.pivot(index="regime", columns="outcome_group", values="share").reindex(index=REGIME_ORDER, columns=outcome_order).fillna(0)
fig, ax = plt.subplots(figsize=(11, 6.5), constrained_layout=True)
bottom = np.zeros(len(pivot))
for outcome, color in zip(outcome_order, outcome_colors):
    values = pivot[outcome].to_numpy()
    if values.sum() == 0:
        continue
    ax.bar(pivot.index, values, bottom=bottom, label=outcome, color=color)
    bottom += values
ax.set_ylim(0, 1)
ax.set_ylabel("Share of evaluated builder-question cases")
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.legend(frameon=False, bbox_to_anchor=(1.02, 1), loc="upper left")
save_figure(fig, "03_error_composition_by_regime")
plt.show()

# %% [markdown]
# ## Figure 4.7.4 — RR effects by question type
#
# Incremental effects are plotted separately for retrieval and answer metrics. This reveals cases such as improved
# temporal retrieval without improved temporal answering.

# %%
fig, axes = plt.subplots(2, 2, figsize=(13.5, 8.8), constrained_layout=True)
qtypes = ["comparison", "inference", "temporal", "unanswerable"]
for ax, metric in zip(axes.flat, ["retrieval_hit", "retrieval_recall", "answer_correct", "token_f1"]):
    subset = qtype_rr_effects_long.loc[qtype_rr_effects_long["metric"].eq(metric)].set_index("question_type").reindex(qtypes)
    values = subset["incremental_difference"] * 100
    colors = [QUESTION_COLORS[qtype] for qtype in qtypes]
    ax.bar(range(len(qtypes)), values, color=colors)
    ax.axhline(0, color=OKABE_ITO["black"], linewidth=1)
    ax.set_xticks(range(len(qtypes)), [q.title() for q in qtypes], rotation=15)
    ax.set_ylabel(f"{ABLATION_METRICS[metric]} change (pp)")
save_figure(fig, "04_rr_effects_by_question_type")
plt.show()

# %% [markdown]
# ## Figure 4.7.5 — Baseline difficulty and RR harm
#
# Each question is positioned by ER error rate across builders and the net ER+RR−ER correctness change. Questions
# below zero are harmed on average by RR; labels identify the most extreme cases for qualitative inspection.

# %%
answer_subset = question_metrics.loc[
    question_metrics["regime"].isin(["ER", "ER+RR"]),
    ["builder_key", "question_id", "question_type", "regime", "answer_correct"],
]
answer_wide = answer_subset.pivot_table(
    index=["builder_key", "question_id", "question_type"],
    columns="regime", values="answer_correct", aggfunc="mean",
).dropna(subset=["ER", "ER+RR"])
question_rr = (
    answer_wide.assign(
        er_error=1 - answer_wide["ER"],
        rr_difference=answer_wide["ER+RR"] - answer_wide["ER"],
    )
    .reset_index()
    .groupby(["question_id", "question_type"], observed=True)
    .agg(er_error_rate=("er_error", "mean"), rr_correctness_change=("rr_difference", "mean"))
    .reset_index()
    .merge(questions[["question_id", "question"]], on="question_id", how="left")
)
question_rr["absolute_rr_change"] = question_rr["rr_correctness_change"].abs()
save_table(question_rr.sort_values("absolute_rr_change", ascending=False), "question_level_rr_harm_and_benefit")

fig, ax = plt.subplots(figsize=(10, 7), constrained_layout=True)
for qtype, group in question_rr.groupby("question_type"):
    ax.scatter(group["er_error_rate"] * 100, group["rr_correctness_change"] * 100, s=42, color=QUESTION_COLORS[qtype], label=qtype, alpha=0.8)
ax.axhline(0, color=OKABE_ITO["black"], linewidth=1)
ax.set_xlabel("ER answer error rate across builders (%)")
ax.set_ylabel("ER+RR - ER correctness change (percentage points)")
ax.legend(title="Question type", frameon=False)
for row in question_rr.nlargest(8, "absolute_rr_change").itertuples():
    ax.annotate(row.question_id.replace("mhq_", ""), (row.er_error_rate * 100, row.rr_correctness_change * 100), xytext=(4, 4), textcoords="offset points", fontsize=7)
save_figure(fig, "05_baseline_difficulty_and_rr_harm")
plt.show()
