# %% [markdown]
# # 4.4 QA Performance
#
# ## Data Sources
#
# - `../../runs/analysis/analysis_manifest.<hash>.json` — Verified analysis manifest; supplies the active artifact registry, model family and parameter metadata, declared regimes, bootstrap contract, and graph/extraction/ER summary metrics. Create and select it with `analysis-manifest` (or `analysis-manifest --from-report` for archived evaluations).
# - `../../runs/analysis/prespecified_cascade_comparisons.6869b0d1a39bd730.json` — Prespecified cascade comparison artifact; used to validate the declared primary, secondary, and incremental roles and the complete 12-builder comparison coverage.
# - Per-question evaluated metric files (all active builder–regime cells):
#
#   - `../../runs/variants/variant_er_2b1eb0de0420e8a59f0008ff/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_fa60813adc48b7946504cad9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_c41e9c339aaefbc613be1a13/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_12b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_28508ddd03bad1b453b1ac27/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_f6886e1fcfead6531b3c7850/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_4c7fe3e91e1ce688febabbe1/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_1b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_8487befcdc34573a74986444/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_9978ad4c0e3c4eab0acc8705/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_2b68fc1e293f9a495f3b40ab/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_270m in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_6756da7bf5b8ad0e2566fbe9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_c81e35865e785a11de06d57a/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_ed7fe257a2a5d1ca497b9531/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for gemma3_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_a622307fd50890d7409607f8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_e28a4372fd88118216d16237/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_08f00aebc7e4a729e8dcd85a/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_0_8b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_10dd06dabafb539d38f03207/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_eddb01bdeced73ab97c84687/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_bc7870f8d888f47f3c04dd7f/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_2b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_7785257f9a3ab9e4deba47c4/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_893ede1f09002ff3e94bfb02/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_bd4bde9ae57a57287b427725/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_9893de5c1644f5877c3e90a9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_815155ebe19736850367d69c/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_8c9a7dc88373e6144a76f8c1/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen35_9b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_a9a958215c3e4cb3de3f21d8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_80de012f53305f9a0940a820/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_08950d2664ed7148983dc565/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_0_6b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_93e77b517b4667be94abd675/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_366f9ae01c5049637d63f6f8/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_ac097e02ae2ce77f15b38bf6/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_1_7b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_adee32f29f0f739dede254a9/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_36795d6ece2290952528501b/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_29335b5ff560842227e0b995/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_4b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_er_633e154d52ebc2b6587c7f2e/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the ER regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_rr_c4ff77c029f06253ae74878b/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the ER+RR regime; used for retrieval, QA, outcome, latency, and token analyses.
#   - `../../runs/variants/variant_native_805cb2faa8378ddf4d4452a0/metrics/question_metrics.904bfaacde8e272e.jsonl` — 120 per-question evaluation records for qwen3_8b in the Native regime; used for retrieval, QA, outcome, latency, and token analyses.
#
# All source artifacts are read-only. The notebook verifies registry hashes, schemas, record counts, builder–regime coverage, and paired question coverage before analysis.

# %% [markdown]
# ## Analysis contract
#
# The experiment is a cumulative cascade: **Native → ER → ER+RR**. The primary contrast is
# **ER+RR−Native**, the secondary contrast is **ER−Native**, and the incremental ablation is
# **ER+RR−ER**. Uncertainty is estimated by 10,000 paired, question-level bootstrap resamples
# stratified by question type (seed 42), matching the evaluated analysis contract.

# %%
from __future__ import annotations

import hashlib
import json
import math
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

start = Path.cwd().resolve()
candidates = [start, *start.parents, start / "experiment", start.parent / "experiment"]
PROJECT_ROOT = next(
    path for path in candidates
    if (path / "configs" / "experiment.yaml").is_file() and (path / "runs" / "analysis").is_dir()
)
SECTION_FOLDER = '4.4 QA Performance'
NOTEBOOK_DIR = PROJECT_ROOT / "analysis" / SECTION_FOLDER
OUTPUT_DIR = NOTEBOOK_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
os.environ.setdefault("MPLCONFIGDIR", str(OUTPUT_DIR / ".matplotlib"))

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from cycler import cycler
from IPython.display import Markdown, display
from matplotlib.colors import LinearSegmentedColormap, TwoSlopeNorm
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.ticker import PercentFormatter

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 100)
pd.set_option("display.float_format", lambda value: f"{value:,.4f}")

OKABE_ITO = {
    "orange": "#E69F00",
    "sky_blue": "#56B4E9",
    "bluish_green": "#009E73",
    "yellow": "#F0E442",
    "blue": "#0072B2",
    "vermillion": "#D55E00",
    "reddish_purple": "#CC79A7",
    "black": "#000000",
}
OKABE_CYCLE = [
    OKABE_ITO["blue"], OKABE_ITO["orange"], OKABE_ITO["bluish_green"],
    OKABE_ITO["vermillion"], OKABE_ITO["sky_blue"],
    OKABE_ITO["reddish_purple"], OKABE_ITO["yellow"], OKABE_ITO["black"],
]
REGIME_ORDER = ["Native", "ER", "ER+RR"]
REGIME_INTERNAL = {
    "Native": "native_lightrag",
    "ER": "advanced_lightrag_er",
    "ER+RR": "advanced_lightrag_er_rr",
}
REGIME_LABEL = {value: key for key, value in REGIME_INTERNAL.items()}
REGIME_COLORS = {
    "Native": OKABE_ITO["black"],
    "ER": OKABE_ITO["blue"],
    "ER+RR": OKABE_ITO["vermillion"],
}
FAMILY_COLORS = {
    "qwen3.5": OKABE_ITO["blue"],
    "qwen3": OKABE_ITO["orange"],
    "gemma3": OKABE_ITO["bluish_green"],
}
QUESTION_COLORS = {
    "comparison": OKABE_ITO["sky_blue"],
    "inference": OKABE_ITO["bluish_green"],
    "temporal": OKABE_ITO["orange"],
    "unanswerable": OKABE_ITO["reddish_purple"],
}
CONTRASTS = [
    ("Primary: ER+RR−Native", "Native", "ER+RR"),
    ("Secondary: ER−Native", "Native", "ER"),
    ("Incremental: ER+RR−ER", "ER", "ER+RR"),
]
CONTRAST_COLORS = {
    "Primary: ER+RR−Native": OKABE_ITO["bluish_green"],
    "Secondary: ER−Native": OKABE_ITO["sky_blue"],
    "Incremental: ER+RR−ER": OKABE_ITO["orange"],
}
CHANGE_CMAP = LinearSegmentedColormap.from_list(
    "okabe_change", [OKABE_ITO["vermillion"], "#FFFFFF", OKABE_ITO["blue"]]
)

plt.rcParams.update({
    "figure.dpi": 120,
    "savefig.dpi": 320,
    "font.family": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,
    "axes.unicode_minus": False,
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "axes.grid": True,
    "grid.alpha": 0.20,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.prop_cycle": cycler(color=OKABE_CYCLE),
})

def sha256_file(path: Path) -> str:
    digest = hashlib.sha256()
    with path.open("rb") as handle:
        for block in iter(lambda: handle.read(1024 * 1024), b""):
            digest.update(block)
    return digest.hexdigest()

def resolve_registry_path(raw_path: str) -> Path:
    path = Path(raw_path)
    if path.is_file():
        return path
    parts = path.parts
    if "runs" not in parts:
        raise FileNotFoundError(path)
    return PROJECT_ROOT / Path(*parts[parts.index("runs"):])

def read_jsonl(path: Path) -> pd.DataFrame:
    with path.open(encoding="utf-8") as handle:
        records = [json.loads(line) for line in handle if line.strip()]
    return pd.DataFrame(records)

def save_table(frame: pd.DataFrame, stem: str, index: bool = False) -> None:
    csv_path = OUTPUT_DIR / f"{stem}.csv"
    tex_path = OUTPUT_DIR / f"{stem}.tex"
    frame.to_csv(csv_path, index=index)
    latex_frame = frame.replace([np.inf, -np.inf], np.nan)
    tex_path.write_text(
        latex_frame.to_latex(index=index, float_format=lambda value: f"{value:.4f}", na_rep="—"),
        encoding="utf-8",
    )

def save_figure(fig: plt.Figure, stem: str) -> None:
    fig.savefig(OUTPUT_DIR / f"{stem}.png", dpi=320, bbox_inches="tight", facecolor="white")
    fig.savefig(OUTPUT_DIR / f"{stem}.svg", bbox_inches="tight", facecolor="white")

def stratified_mean_ci(
    frame: pd.DataFrame,
    value_col: str,
    *,
    samples: int = 10_000,
    seed: int = 42,
) -> tuple[float, float, float, int]:
    clean_frame = frame[["question_type", value_col]].dropna()
    arrays = [
        group[value_col].to_numpy(dtype=float)
        for _, group in clean_frame.groupby("question_type", sort=True)
        if len(group)
    ]
    if not arrays:
        return (np.nan, np.nan, np.nan, 0)
    observed = np.concatenate(arrays)
    rng = np.random.default_rng(seed)
    bootstrap_sum = np.zeros(samples, dtype=float)
    for values in arrays:
        indices = rng.integers(0, len(values), size=(samples, len(values)))
        bootstrap_sum += values[indices].sum(axis=1)
    bootstrap_means = bootstrap_sum / len(observed)
    lower, upper = np.quantile(bootstrap_means, [0.025, 0.975])
    return float(observed.mean()), float(lower), float(upper), int(len(observed))

def metric_question_level(metric: str, regime: str, builder: str | None = None) -> pd.DataFrame:
    subset = question_metrics.loc[
        question_metrics["graph_regime"].eq(REGIME_INTERNAL[regime]),
        ["builder_key", "question_id", "question_type", metric],
    ].dropna(subset=[metric])
    if builder is not None:
        subset = subset.loc[subset["builder_key"].eq(builder)]
    return (
        subset.groupby(["question_id", "question_type"], as_index=False, observed=True)[metric]
        .mean()
    )

def contrast_question_level(
    metric: str,
    left: str,
    right: str,
    builder: str | None = None,
) -> pd.DataFrame:
    subset = question_metrics[
        ["builder_key", "question_id", "question_type", "graph_regime", metric]
    ].dropna(subset=[metric])
    if builder is not None:
        subset = subset.loc[subset["builder_key"].eq(builder)]
    wide = subset.pivot_table(
        index=["builder_key", "question_id", "question_type"],
        columns="graph_regime",
        values=metric,
        aggfunc="mean",
    )
    left_key, right_key = REGIME_INTERNAL[left], REGIME_INTERNAL[right]
    paired = wide.dropna(subset=[left_key, right_key]).copy()
    paired["difference"] = paired[right_key] - paired[left_key]
    return (
        paired.reset_index()
        .groupby(["question_id", "question_type"], as_index=False, observed=True)["difference"]
        .mean()
    )

def overall_metric_estimate(metric: str, regime: str) -> dict:
    frame = metric_question_level(metric, regime)
    mean, lower, upper, count = stratified_mean_ci(frame, metric)
    return {
        "metric": metric, "regime": regime, "mean": mean,
        "ci_lower": lower, "ci_upper": upper, "question_count": count,
    }

def contrast_metric_estimate(
    metric: str,
    contrast: str,
    left: str,
    right: str,
    builder: str | None = None,
    seed: int = 42,
) -> dict:
    frame = contrast_question_level(metric, left, right, builder)
    mean, lower, upper, count = stratified_mean_ci(
        frame, "difference", seed=seed
    )
    left_frame = metric_question_level(metric, left, builder)
    left_mean = left_frame[metric].mean()
    relative = 100 * mean / left_mean if pd.notna(left_mean) and left_mean != 0 else np.nan
    return {
        "builder_key": builder,
        "contrast": contrast,
        "metric": metric,
        "left_regime": left,
        "right_regime": right,
        "left_mean": left_mean,
        "mean_difference": mean,
        "ci_lower": lower,
        "ci_upper": upper,
        "relative_difference_percent": relative,
        "paired_question_count": count,
    }

print(f"Project root: {PROJECT_ROOT}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Project root: .
# Output directory: analysis/4.4 QA Performance/output

# %% [markdown]
# ## Load and validate the evaluated data
#
# The active input registry in the global report is authoritative. This avoids accidentally
# including historical variants while still checking every file against its recorded hash,
# schema, row count, regime, and paired coverage.

# %%
GLOBAL_REPORT_PATH = PROJECT_ROOT / "runs" / "analysis" / (PROJECT_ROOT / "runs" / "analysis" / "analysis_manifest.path").read_text().strip()
global_report = json.loads(GLOBAL_REPORT_PATH.read_text(encoding="utf-8"))
assert global_report["schema_version"] == "1.0.0"
assert global_report["builder_count"] == 12
assert global_report["expected_question_count"] == 120
assert global_report["graph_regimes"] == list(REGIME_LABEL)
assert global_report["bootstrap"] == {
    "cluster_unit": "question_id",
    "confidence_level": 0.95,
    "method": "paired_stratified_percentile_by_question_type",
    "samples": 10000,
    "seed": 42,
    "shared_resample_plan": True,
}

builder_meta = pd.DataFrame([
    {
        "builder_key": row["builder_key"],
        "display_name": row["display_name"],
        "family": row["family"],
        "parameter_billions": row["parameter_billions"],
        "scale_band": row["scale_band"],
    }
    for row in global_report["builder_performance"]
])
builder_order = builder_meta["builder_key"].tolist()
display_order = builder_meta["display_name"].tolist()
builder_lookup = builder_meta.set_index("builder_key").to_dict("index")

metric_entries = []
for logical_name, metadata in global_report["input_artifacts"].items():
    parts = logical_name.split("/")
    if len(parts) == 2 and parts[1] in REGIME_LABEL:
        metric_entries.append((parts[0], parts[1], metadata))
metric_entries.sort(key=lambda item: (builder_order.index(item[0]), list(REGIME_LABEL).index(item[1])))
assert len(metric_entries) == 36

frames = []
validation_rows = []
required_columns = {
    "question_id", "question_type", "graph_regime", "builder_model",
    "retrieval_hit", "retrieval_recall", "reciprocal_rank",
    "answer_correct", "token_f1", "retrieval_latency_ms",
    "answer_latency_ms", "context_token_count", "answer_total_tokens",
}
for builder_key, regime, metadata in metric_entries:
    path = resolve_registry_path(metadata["path"])
    frame = read_jsonl(path)
    missing = required_columns.difference(frame.columns)
    if missing:
        raise ValueError(f"{path} is missing required fields: {sorted(missing)}")
    actual_hash = sha256_file(path)
    valid = (
        actual_hash == metadata["sha256"]
        and len(frame) == metadata["record_count"] == 120
        and set(frame["schema_version"]) == {metadata["schema_version"]} and metadata["schema_version"] in {"3.0.0", "4.0.0"}
        and set(frame["graph_regime"]) == {regime}
    )
    if not valid:
        raise ValueError(f"Artifact validation failed: {path}")
    frame["builder_key"] = builder_key
    frames.append(frame)
    validation_rows.append({
        "builder_key": builder_key,
        "regime": REGIME_LABEL[regime],
        "relative_path": path.relative_to(PROJECT_ROOT).as_posix(),
        "records": len(frame),
        "schema_version": metadata["schema_version"],
        "sha256_verified": actual_hash == metadata["sha256"],
    })

question_metrics = pd.concat(frames, ignore_index=True)
question_metrics = question_metrics.merge(builder_meta, on="builder_key", how="left", validate="many_to_one")
question_metrics["regime"] = question_metrics["graph_regime"].map(REGIME_LABEL)
question_metrics["regime"] = pd.Categorical(
    question_metrics["regime"], categories=REGIME_ORDER, ordered=True
)
question_metrics["builder_key"] = pd.Categorical(
    question_metrics["builder_key"], categories=builder_order, ordered=True
)
source_validation = pd.DataFrame(validation_rows)

coverage = (
    question_metrics.groupby(["builder_key", "regime"], observed=True)["question_id"]
    .nunique().unstack()
)
if question_metrics.shape[0] != 4_320 or not coverage.eq(120).all().all():
    raise ValueError(f"Unexpected evaluated coverage: rows={len(question_metrics)}")
if question_metrics[["builder_key", "regime", "question_id"]].duplicated().any():
    raise ValueError("Duplicate builder–regime–question rows detected")

save_table(source_validation, "source_validation")
display(source_validation)
print(f"Validated {len(source_validation)} source files and {len(question_metrics):,} evaluated rows.")
print(f"Question types: {question_metrics['question_type'].value_counts().to_dict()}")

# %% [markdown]
# ## Descriptive QA performance
#
# End-to-end answer quality is separated into correctness, lexical overlap, abstention, and hallucination.
# Undefined metrics are excluded only from their relevant denominators (for example, unanswerable accuracy is
# estimated on the unanswerable stratum).

# %%
PRIMARY_PATH = PROJECT_ROOT / "runs" / "analysis" / "prespecified_cascade_comparisons.6869b0d1a39bd730.json"
primary_report = json.loads(PRIMARY_PATH.read_text(encoding="utf-8"))
assert primary_report["schema_version"] == "2.0.0"
assert primary_report["builder_count"] == 12
assert primary_report["total_prespecified_comparison_count"] == 36

QA_METRICS = {
    "answer_correct": ("Answer correctness", True),
    "token_f1": ("Token F1", True),
    "over_abstention": ("Over-abstention rate", False),
    "hallucination": ("Hallucination rate", False),
    "unanswerable_correct": ("Unanswerable accuracy", True),
}
qa_model_summary = (
    question_metrics.groupby(
        ["builder_key", "display_name", "family", "parameter_billions", "regime"],
        observed=True,
    )
    .agg(
        answer_correct=("answer_correct", "mean"),
        token_f1=("token_f1", "mean"),
        answer_exact_match=("answer_exact_match", "mean"),
        over_abstention=("over_abstention", "mean"),
        hallucination=("hallucination", "mean"),
        unanswerable_correct=("unanswerable_correct", "mean"),
        answer_latency_ms=("answer_latency_ms", "mean"),
        evaluated_questions=("question_id", "nunique"),
    )
    .reset_index()
)
qa_family_summary = (
    qa_model_summary.groupby(["family", "regime"], observed=True)
    .agg({
        "answer_correct": ["mean", "std", "min", "max"],
        "token_f1": ["mean", "std"],
        "over_abstention": ["mean", "std"],
        "hallucination": ["mean", "std"],
        "unanswerable_correct": ["mean", "std"],
    })
)
qa_family_summary.columns = ["_".join(column) for column in qa_family_summary.columns]
qa_family_summary = qa_family_summary.reset_index()
qa_overall = pd.DataFrame([
    overall_metric_estimate(metric, regime)
    for metric in QA_METRICS
    for regime in REGIME_ORDER
])
save_table(qa_model_summary, "qa_summary_by_model_and_regime")
save_table(qa_family_summary, "qa_summary_by_family_and_regime")
save_table(qa_overall, "qa_overall_estimates_with_ci")
display(qa_overall)
# Out:
#                   metric  regime   mean  ci_lower  ci_upper  question_count
# 0         answer_correct  Native 0.2896    0.2444    0.3354             120
# 1         answer_correct      ER 0.3215    0.2764    0.3660             120
# 2         answer_correct   ER+RR 0.3201    0.2764    0.3632             120
# 3               token_f1  Native 0.1625    0.1150    0.2129              90
# 4               token_f1      ER 0.1888    0.1414    0.2357              90
# 5               token_f1   ER+RR 0.1834    0.1361    0.2299              90
# 6        over_abstention  Native 0.6352    0.5759    0.6917              90
# 7        over_abstention      ER 0.6324    0.5750    0.6870              90
# 8        over_abstention   ER+RR 0.6315    0.5750    0.6852              90
# 9          hallucination  Native 0.2889    0.1889    0.4000              30
# 10         hallucination      ER 0.2417    0.1417    0.3528              30
# 11         hallucination   ER+RR 0.2306    0.1333    0.3389              30
# 12  unanswerable_correct  Native 0.7111    0.6000    0.8111              30
# 13  unanswerable_correct      ER 0.7583    0.6472    0.8583              30
# 14  unanswerable_correct   ER+RR 0.7694    0.6611    0.8667              30

# %% [markdown]
# ## Paired QA effects and variability
#
# Treatment effects are computed on identical questions. For error rates, a negative difference is beneficial;
# the saved table retains raw direction while the oriented heatmap below converts every metric to “positive is better.”

# %%
qa_contrasts = pd.DataFrame([
    contrast_metric_estimate(metric, contrast, left, right)
    for contrast, left, right in CONTRASTS
    for metric in QA_METRICS
])
qa_builder_effects = pd.DataFrame([
    contrast_metric_estimate(
        metric, contrast, left, right, builder=builder,
        seed=142 + builder_order.index(builder),
    )
    for builder in builder_order
    for contrast, left, right in CONTRASTS
    for metric in QA_METRICS
]).merge(builder_meta, on="builder_key", how="left")
qa_question_type = (
    question_metrics.groupby(["regime", "question_type"], observed=True)
    .agg({
        "answer_correct": "mean",
        "token_f1": "mean",
        "over_abstention": "mean",
        "hallucination": "mean",
        "unanswerable_correct": "mean",
    })
    .reset_index()
)
save_table(qa_contrasts, "qa_cascade_contrasts")
save_table(qa_builder_effects, "qa_effects_by_builder")
save_table(qa_question_type, "qa_by_question_type")
display(qa_contrasts)
# Out:
#    builder_key               contrast                metric left_regime  \
# 0         None  Primary: ER+RR−Native        answer_correct      Native
# 1         None  Primary: ER+RR−Native              token_f1      Native
# 2         None  Primary: ER+RR−Native       over_abstention      Native
# 3         None  Primary: ER+RR−Native         hallucination      Native
# 4         None  Primary: ER+RR−Native  unanswerable_correct      Native
# 5         None   Secondary: ER−Native        answer_correct      Native
# 6         None   Secondary: ER−Native              token_f1      Native
# 7         None   Secondary: ER−Native       over_abstention      Native
# 8         None   Secondary: ER−Native         hallucination      Native
# 9         None   Secondary: ER−Native  unanswerable_correct      Native
# 10        None  Incremental: ER+RR−ER        answer_correct          ER
# 11        None  Incremental: ER+RR−ER              token_f1          ER
# 12        None  Incremental: ER+RR−ER       over_abstention          ER
# 13        None  Incremental: ER+RR−ER         hallucination          ER
# 14        None  Incremental: ER+RR−ER  unanswerable_correct          ER
#
#    right_regime  left_mean  mean_difference  ci_lower  ci_upper  \
# 0         ER+RR     0.2896           0.0306    0.0118    0.0500
# 1         ER+RR     0.1625           0.0209    0.0028    0.0398
# 2         ER+RR     0.6352          -0.0037   -0.0324    0.0241
# 3         ER+RR     0.2889          -0.0583   -0.1139   -0.0056
# 4         ER+RR     0.7111           0.0583    0.0056    0.1139
# 5            ER     0.2896           0.0319    0.0132    0.0514
# 6            ER     0.1625           0.0263    0.0074    0.0455
# 7            ER     0.6352          -0.0028   -0.0306    0.0250
# 8            ER     0.2889          -0.0472   -0.0944    0.0000
# 9            ER     0.7111           0.0472   -0.0000    0.0944
# 10        ER+RR     0.3215          -0.0014   -0.0118    0.0097
# 11        ER+RR     0.1888          -0.0054   -0.0158    0.0057
# 12        ER+RR     0.6324          -0.0009   -0.0157    0.0130
# 13        ER+RR     0.2417          -0.0111   -0.0444    0.0167
# 14        ER+RR     0.7583           0.0111   -0.0167    0.0444
#
#     relative_difference_percent  paired_question_count
# 0                       10.5516                    120
# 1                       12.8878                     90
# 2                       -0.5831                     90
# 3                      -20.1923                     30
# 4                        8.2031                     30
# 5                       11.0312                    120
# 6                       16.1938                     90
# 7                       -0.4373                     90
# 8                      -16.3462                     30
# 9                        6.6406                     30
# 10                      -0.4320                    120
# 11                      -2.8452                     90
# 12                      -0.1464                     90
# 13                      -4.5977                     30
# 14                       1.4652                     30

# %% [markdown]
# ## Figure 4.4.1 — Paired QA effects
#
# Points show paired mean differences in percentage points; horizontal intervals are question-clustered 95%
# bootstrap confidence intervals. The two contrasts separate the ER contribution from the incremental RR
# contribution. For over-abstention and hallucination, negative effects indicate improvement; for the other
# three metrics, positive effects indicate improvement.

# %%
forest_contrasts = ["Secondary: ER−Native", "Incremental: ER+RR−ER"]
forest_labels = {
    "Secondary: ER−Native": r"$\mathrm{ER} - \mathrm{Native}$",
    "Incremental: ER+RR−ER": r"$\mathrm{ER+RR} - \mathrm{ER}$",
}
forest_offsets = {"Secondary: ER−Native": -0.12, "Incremental: ER+RR−ER": 0.12}
metric_order = [metric for metric in QA_METRICS if metric != "unanswerable_correct"]
y_positions = np.arange(len(metric_order))

fig, ax = plt.subplots(figsize=(7.4, 4.2), constrained_layout=True)
ax.axvline(0, color="#4D4D4D", linestyle="--", linewidth=1.3, zorder=0)
for contrast in forest_contrasts:
    subset = (
        qa_contrasts.loc[qa_contrasts["contrast"].eq(contrast)]
        .set_index("metric")
        .reindex(metric_order)
    )
    estimates = subset["mean_difference"].to_numpy() * 100
    lower = subset["ci_lower"].to_numpy() * 100
    upper = subset["ci_upper"].to_numpy() * 100
    errors = np.vstack([estimates - lower, upper - estimates])
    ax.errorbar(
        estimates,
        y_positions + forest_offsets[contrast],
        xerr=errors,
        fmt="o",
        markersize=7.5,
        capsize=3.5,
        linewidth=1.8,
        color=CONTRAST_COLORS[contrast],
        label=forest_labels[contrast],
        zorder=3,
    )

ax.set_yticks(y_positions, [QA_METRICS[metric][0] for metric in metric_order])
ax.invert_yaxis()
ax.set_xlabel("Paired mean difference (percentage points)")
ax.grid(axis="x", alpha=0.22)
ax.grid(axis="y", visible=False)
ax.margins(x=0.08, y=0.16)
ax.legend(title="Paired contrast", loc="lower right", frameon=False)
save_figure(fig, "01_absolute_qa_outcomes")
plt.show()

# %% [markdown]
# ## Figure 4.4.2 — Builder heterogeneity in the primary QA effect
#
# Effects are direction-normalised so that blue indicates improvement for every column. This prevents lower
# abstention or hallucination rates from being visually misread as deterioration. Unanswerable accuracy is
# omitted because it is the exact complement of hallucination rate on the unanswerable subset.

# %%
oriented = qa_builder_effects.query("contrast == 'Primary: ER+RR−Native'").copy()
oriented["oriented_effect"] = oriented["mean_difference"]
lower_is_better = {"over_abstention", "hallucination"}
oriented.loc[oriented["metric"].isin(lower_is_better), "oriented_effect"] *= -1
heatmap_metrics = [metric for metric in QA_METRICS if metric != "unanswerable_correct"]
qa_matrix = (
    oriented.pivot(index="display_name", columns="metric", values="oriented_effect")
    .reindex(index=display_order, columns=heatmap_metrics) * 100
)
limit = max(1.0, np.nanmax(np.abs(qa_matrix.to_numpy())))
fig, ax = plt.subplots(figsize=(11.5, 7.2), constrained_layout=True)
image = ax.imshow(qa_matrix, aspect="auto", cmap=CHANGE_CMAP, norm=TwoSlopeNorm(vmin=-limit, vcenter=0, vmax=limit))
ax.set_xticks(range(qa_matrix.shape[1]), [QA_METRICS[key][0] for key in qa_matrix.columns], rotation=20, ha="right")
ax.set_yticks(range(qa_matrix.shape[0]), qa_matrix.index)
for row in range(qa_matrix.shape[0]):
    for column in range(qa_matrix.shape[1]):
        value = qa_matrix.iloc[row, column]
        if pd.notna(value):
            ax.text(column, row, f"{value:+.1f}", ha="center", va="center", fontsize=8)
colorbar = fig.colorbar(image, ax=ax, pad=0.02)
colorbar.set_label("Direction-normalised ER+RR - Native change (percentage points)")
save_figure(fig, "02_primary_qa_effect_heatmap")
plt.show()

# %% [markdown]
# ## Tables 4.4.1–4.4.3 — Absolute QA metrics by regime
#
# The tables report absolute metric levels for every builder, complementing the direction-normalised change heatmap above.
# All entries are percentages. Answer correctness uses all 120 questions; Token F1 and over-abstention use the 90
# answerable questions; hallucination rate uses the 30 unanswerable questions.

# %%
absolute_metric_columns = [
    "answer_correct", "token_f1", "over_abstention", "hallucination"
]
absolute_column_labels = {
    "display_name": "Model",
    "answer_correct": "Answer correctness (%)",
    "token_f1": "Token F1 (%)",
    "over_abstention": "Over-abstention rate (%)",
    "hallucination": "Hallucination rate (%)",
}
absolute_table_stems = {
    "Native": "qa_absolute_metrics_native",
    "ER": "qa_absolute_metrics_er",
    "ER+RR": "qa_absolute_metrics_er_rr",
}
absolute_table_numbers = {"Native": "4.4.1", "ER": "4.4.2", "ER+RR": "4.4.3"}
qa_absolute_tables = {}

for regime in REGIME_ORDER:
    table = (
        qa_model_summary.loc[
            qa_model_summary["regime"].eq(regime),
            ["display_name", *absolute_metric_columns],
        ]
        .set_index("display_name")
        .reindex(display_order)
        .mul({column: 100 for column in absolute_metric_columns})
        .reset_index()
        .rename(columns=absolute_column_labels)
    )
    qa_absolute_tables[regime] = table
    save_table(table, absolute_table_stems[regime])
    display(Markdown(f"### Table {absolute_table_numbers[regime]} — {regime}"))
    display(
        table.style.hide(axis="index").format(
            {column: "{:.1f}" for column in table.columns if column != "Model"}
        )
    )
# Out:
# ### Table 4.4.1 — Native
# <style type="text/css">
# </style>
# <table id="T_6bad8">
#   <thead>
#     <tr>
#       <th id="T_6bad8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6bad8_level0_col1" class="col_heading level0 col1" >Answer correctness (%)</th>
#       <th id="T_6bad8_level0_col2" class="col_heading level0 col2" >Token F1 (%)</th>
#       <th id="T_6bad8_level0_col3" class="col_heading level0 col3" >Over-abstention rate (%)</th>
#       <th id="T_6bad8_level0_col4" class="col_heading level0 col4" >Hallucination rate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6bad8_row0_col0" class="data row0 col0" >Qwen3.5 0.8B</td>
#       <td id="T_6bad8_row0_col1" class="data row0 col1" >28.3</td>
#       <td id="T_6bad8_row0_col2" class="data row0 col2" >12.9</td>
#       <td id="T_6bad8_row0_col3" class="data row0 col3" >63.3</td>
#       <td id="T_6bad8_row0_col4" class="data row0 col4" >23.3</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row1_col0" class="data row1 col0" >Qwen3.5 2B</td>
#       <td id="T_6bad8_row1_col1" class="data row1 col1" >26.7</td>
#       <td id="T_6bad8_row1_col2" class="data row1 col2" >15.9</td>
#       <td id="T_6bad8_row1_col3" class="data row1 col3" >63.3</td>
#       <td id="T_6bad8_row1_col4" class="data row1 col4" >36.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row2_col0" class="data row2 col0" >Qwen3.5 4B</td>
#       <td id="T_6bad8_row2_col1" class="data row2 col1" >29.2</td>
#       <td id="T_6bad8_row2_col2" class="data row2 col2" >15.6</td>
#       <td id="T_6bad8_row2_col3" class="data row2 col3" >63.3</td>
#       <td id="T_6bad8_row2_col4" class="data row2 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row3_col0" class="data row3 col0" >Qwen3.5 9B</td>
#       <td id="T_6bad8_row3_col1" class="data row3 col1" >28.3</td>
#       <td id="T_6bad8_row3_col2" class="data row3 col2" >15.1</td>
#       <td id="T_6bad8_row3_col3" class="data row3 col3" >67.8</td>
#       <td id="T_6bad8_row3_col4" class="data row3 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row4_col0" class="data row4 col0" >Qwen3 0.6B</td>
#       <td id="T_6bad8_row4_col1" class="data row4 col1" >25.0</td>
#       <td id="T_6bad8_row4_col2" class="data row4 col2" >11.1</td>
#       <td id="T_6bad8_row4_col3" class="data row4 col3" >74.4</td>
#       <td id="T_6bad8_row4_col4" class="data row4 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row5_col0" class="data row5 col0" >Qwen3 1.7B</td>
#       <td id="T_6bad8_row5_col1" class="data row5 col1" >33.3</td>
#       <td id="T_6bad8_row5_col2" class="data row5 col2" >16.0</td>
#       <td id="T_6bad8_row5_col3" class="data row5 col3" >67.8</td>
#       <td id="T_6bad8_row5_col4" class="data row5 col4" >13.3</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row6_col0" class="data row6 col0" >Qwen3 4B</td>
#       <td id="T_6bad8_row6_col1" class="data row6 col1" >30.0</td>
#       <td id="T_6bad8_row6_col2" class="data row6 col2" >16.7</td>
#       <td id="T_6bad8_row6_col3" class="data row6 col3" >66.7</td>
#       <td id="T_6bad8_row6_col4" class="data row6 col4" >23.3</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row7_col0" class="data row7 col0" >Qwen3 8B</td>
#       <td id="T_6bad8_row7_col1" class="data row7 col1" >28.3</td>
#       <td id="T_6bad8_row7_col2" class="data row7 col2" >24.1</td>
#       <td id="T_6bad8_row7_col3" class="data row7 col3" >48.9</td>
#       <td id="T_6bad8_row7_col4" class="data row7 col4" >53.3</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row8_col0" class="data row8 col0" >Gemma 3 270M</td>
#       <td id="T_6bad8_row8_col1" class="data row8 col1" >29.2</td>
#       <td id="T_6bad8_row8_col2" class="data row8 col2" >15.9</td>
#       <td id="T_6bad8_row8_col3" class="data row8 col3" >66.7</td>
#       <td id="T_6bad8_row8_col4" class="data row8 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row9_col0" class="data row9 col0" >Gemma 3 1B</td>
#       <td id="T_6bad8_row9_col1" class="data row9 col1" >29.2</td>
#       <td id="T_6bad8_row9_col2" class="data row9 col2" >19.0</td>
#       <td id="T_6bad8_row9_col3" class="data row9 col3" >54.4</td>
#       <td id="T_6bad8_row9_col4" class="data row9 col4" >36.7</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row10_col0" class="data row10 col0" >Gemma 3 4B</td>
#       <td id="T_6bad8_row10_col1" class="data row10 col1" >28.3</td>
#       <td id="T_6bad8_row10_col2" class="data row10 col2" >15.8</td>
#       <td id="T_6bad8_row10_col3" class="data row10 col3" >67.8</td>
#       <td id="T_6bad8_row10_col4" class="data row10 col4" >33.3</td>
#     </tr>
#     <tr>
#       <td id="T_6bad8_row11_col0" class="data row11 col0" >Gemma 3 12B</td>
#       <td id="T_6bad8_row11_col1" class="data row11 col1" >31.7</td>
#       <td id="T_6bad8_row11_col2" class="data row11 col2" >16.8</td>
#       <td id="T_6bad8_row11_col3" class="data row11 col3" >57.8</td>
#       <td id="T_6bad8_row11_col4" class="data row11 col4" >20.0</td>
#     </tr>
#   </tbody>
# </table>
# ### Table 4.4.2 — ER
# <style type="text/css">
# </style>
# <table id="T_1ae82">
#   <thead>
#     <tr>
#       <th id="T_1ae82_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1ae82_level0_col1" class="col_heading level0 col1" >Answer correctness (%)</th>
#       <th id="T_1ae82_level0_col2" class="col_heading level0 col2" >Token F1 (%)</th>
#       <th id="T_1ae82_level0_col3" class="col_heading level0 col3" >Over-abstention rate (%)</th>
#       <th id="T_1ae82_level0_col4" class="col_heading level0 col4" >Hallucination rate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ae82_row0_col0" class="data row0 col0" >Qwen3.5 0.8B</td>
#       <td id="T_1ae82_row0_col1" class="data row0 col1" >36.7</td>
#       <td id="T_1ae82_row0_col2" class="data row0 col2" >21.7</td>
#       <td id="T_1ae82_row0_col3" class="data row0 col3" >64.4</td>
#       <td id="T_1ae82_row0_col4" class="data row0 col4" >16.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row1_col0" class="data row1 col0" >Qwen3.5 2B</td>
#       <td id="T_1ae82_row1_col1" class="data row1 col1" >34.2</td>
#       <td id="T_1ae82_row1_col2" class="data row1 col2" >24.6</td>
#       <td id="T_1ae82_row1_col3" class="data row1 col3" >58.9</td>
#       <td id="T_1ae82_row1_col4" class="data row1 col4" >30.0</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row2_col0" class="data row2 col0" >Qwen3.5 4B</td>
#       <td id="T_1ae82_row2_col1" class="data row2 col1" >31.7</td>
#       <td id="T_1ae82_row2_col2" class="data row2 col2" >16.8</td>
#       <td id="T_1ae82_row2_col3" class="data row2 col3" >66.7</td>
#       <td id="T_1ae82_row2_col4" class="data row2 col4" >20.0</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row3_col0" class="data row3 col0" >Qwen3.5 9B</td>
#       <td id="T_1ae82_row3_col1" class="data row3 col1" >35.8</td>
#       <td id="T_1ae82_row3_col2" class="data row3 col2" >19.2</td>
#       <td id="T_1ae82_row3_col3" class="data row3 col3" >66.7</td>
#       <td id="T_1ae82_row3_col4" class="data row3 col4" >13.3</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row4_col0" class="data row4 col0" >Qwen3 0.6B</td>
#       <td id="T_1ae82_row4_col1" class="data row4 col1" >30.0</td>
#       <td id="T_1ae82_row4_col2" class="data row4 col2" >16.6</td>
#       <td id="T_1ae82_row4_col3" class="data row4 col3" >67.8</td>
#       <td id="T_1ae82_row4_col4" class="data row4 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row5_col0" class="data row5 col0" >Qwen3 1.7B</td>
#       <td id="T_1ae82_row5_col1" class="data row5 col1" >30.8</td>
#       <td id="T_1ae82_row5_col2" class="data row5 col2" >18.2</td>
#       <td id="T_1ae82_row5_col3" class="data row5 col3" >65.6</td>
#       <td id="T_1ae82_row5_col4" class="data row5 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row6_col0" class="data row6 col0" >Qwen3 4B</td>
#       <td id="T_1ae82_row6_col1" class="data row6 col1" >32.5</td>
#       <td id="T_1ae82_row6_col2" class="data row6 col2" >15.1</td>
#       <td id="T_1ae82_row6_col3" class="data row6 col3" >68.9</td>
#       <td id="T_1ae82_row6_col4" class="data row6 col4" >13.3</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row7_col0" class="data row7 col0" >Qwen3 8B</td>
#       <td id="T_1ae82_row7_col1" class="data row7 col1" >30.8</td>
#       <td id="T_1ae82_row7_col2" class="data row7 col2" >19.2</td>
#       <td id="T_1ae82_row7_col3" class="data row7 col3" >57.8</td>
#       <td id="T_1ae82_row7_col4" class="data row7 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row8_col0" class="data row8 col0" >Gemma 3 270M</td>
#       <td id="T_1ae82_row8_col1" class="data row8 col1" >27.5</td>
#       <td id="T_1ae82_row8_col2" class="data row8 col2" >16.9</td>
#       <td id="T_1ae82_row8_col3" class="data row8 col3" >61.1</td>
#       <td id="T_1ae82_row8_col4" class="data row8 col4" >36.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row9_col0" class="data row9 col0" >Gemma 3 1B</td>
#       <td id="T_1ae82_row9_col1" class="data row9 col1" >30.0</td>
#       <td id="T_1ae82_row9_col2" class="data row9 col2" >18.9</td>
#       <td id="T_1ae82_row9_col3" class="data row9 col3" >61.1</td>
#       <td id="T_1ae82_row9_col4" class="data row9 col4" >33.3</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row10_col0" class="data row10 col0" >Gemma 3 4B</td>
#       <td id="T_1ae82_row10_col1" class="data row10 col1" >29.2</td>
#       <td id="T_1ae82_row10_col2" class="data row10 col2" >19.4</td>
#       <td id="T_1ae82_row10_col3" class="data row10 col3" >57.8</td>
#       <td id="T_1ae82_row10_col4" class="data row10 col4" >36.7</td>
#     </tr>
#     <tr>
#       <td id="T_1ae82_row11_col0" class="data row11 col0" >Gemma 3 12B</td>
#       <td id="T_1ae82_row11_col1" class="data row11 col1" >36.7</td>
#       <td id="T_1ae82_row11_col2" class="data row11 col2" >20.0</td>
#       <td id="T_1ae82_row11_col3" class="data row11 col3" >62.2</td>
#       <td id="T_1ae82_row11_col4" class="data row11 col4" >10.0</td>
#     </tr>
#   </tbody>
# </table>
# ### Table 4.4.3 — ER+RR
# <style type="text/css">
# </style>
# <table id="T_4e2ab">
#   <thead>
#     <tr>
#       <th id="T_4e2ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4e2ab_level0_col1" class="col_heading level0 col1" >Answer correctness (%)</th>
#       <th id="T_4e2ab_level0_col2" class="col_heading level0 col2" >Token F1 (%)</th>
#       <th id="T_4e2ab_level0_col3" class="col_heading level0 col3" >Over-abstention rate (%)</th>
#       <th id="T_4e2ab_level0_col4" class="col_heading level0 col4" >Hallucination rate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4e2ab_row0_col0" class="data row0 col0" >Qwen3.5 0.8B</td>
#       <td id="T_4e2ab_row0_col1" class="data row0 col1" >31.7</td>
#       <td id="T_4e2ab_row0_col2" class="data row0 col2" >15.2</td>
#       <td id="T_4e2ab_row0_col3" class="data row0 col3" >64.4</td>
#       <td id="T_4e2ab_row0_col4" class="data row0 col4" >16.7</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row1_col0" class="data row1 col0" >Qwen3.5 2B</td>
#       <td id="T_4e2ab_row1_col1" class="data row1 col1" >31.7</td>
#       <td id="T_4e2ab_row1_col2" class="data row1 col2" >22.4</td>
#       <td id="T_4e2ab_row1_col3" class="data row1 col3" >58.9</td>
#       <td id="T_4e2ab_row1_col4" class="data row1 col4" >33.3</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row2_col0" class="data row2 col0" >Qwen3.5 4B</td>
#       <td id="T_4e2ab_row2_col1" class="data row2 col1" >32.5</td>
#       <td id="T_4e2ab_row2_col2" class="data row2 col2" >16.9</td>
#       <td id="T_4e2ab_row2_col3" class="data row2 col3" >66.7</td>
#       <td id="T_4e2ab_row2_col4" class="data row2 col4" >16.7</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row3_col0" class="data row3 col0" >Qwen3.5 9B</td>
#       <td id="T_4e2ab_row3_col1" class="data row3 col1" >34.2</td>
#       <td id="T_4e2ab_row3_col2" class="data row3 col2" >17.0</td>
#       <td id="T_4e2ab_row3_col3" class="data row3 col3" >68.9</td>
#       <td id="T_4e2ab_row3_col4" class="data row3 col4" >13.3</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row4_col0" class="data row4 col0" >Qwen3 0.6B</td>
#       <td id="T_4e2ab_row4_col1" class="data row4 col1" >31.7</td>
#       <td id="T_4e2ab_row4_col2" class="data row4 col2" >18.0</td>
#       <td id="T_4e2ab_row4_col3" class="data row4 col3" >67.8</td>
#       <td id="T_4e2ab_row4_col4" class="data row4 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row5_col0" class="data row5 col0" >Qwen3 1.7B</td>
#       <td id="T_4e2ab_row5_col1" class="data row5 col1" >31.7</td>
#       <td id="T_4e2ab_row5_col2" class="data row5 col2" >19.3</td>
#       <td id="T_4e2ab_row5_col3" class="data row5 col3" >65.6</td>
#       <td id="T_4e2ab_row5_col4" class="data row5 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row6_col0" class="data row6 col0" >Qwen3 4B</td>
#       <td id="T_4e2ab_row6_col1" class="data row6 col1" >32.5</td>
#       <td id="T_4e2ab_row6_col2" class="data row6 col2" >14.9</td>
#       <td id="T_4e2ab_row6_col3" class="data row6 col3" >66.7</td>
#       <td id="T_4e2ab_row6_col4" class="data row6 col4" >10.0</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row7_col0" class="data row7 col0" >Qwen3 8B</td>
#       <td id="T_4e2ab_row7_col1" class="data row7 col1" >30.8</td>
#       <td id="T_4e2ab_row7_col2" class="data row7 col2" >19.8</td>
#       <td id="T_4e2ab_row7_col3" class="data row7 col3" >53.3</td>
#       <td id="T_4e2ab_row7_col4" class="data row7 col4" >26.7</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row8_col0" class="data row8 col0" >Gemma 3 270M</td>
#       <td id="T_4e2ab_row8_col1" class="data row8 col1" >29.2</td>
#       <td id="T_4e2ab_row8_col2" class="data row8 col2" >17.8</td>
#       <td id="T_4e2ab_row8_col3" class="data row8 col3" >63.3</td>
#       <td id="T_4e2ab_row8_col4" class="data row8 col4" >33.3</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row9_col0" class="data row9 col0" >Gemma 3 1B</td>
#       <td id="T_4e2ab_row9_col1" class="data row9 col1" >30.0</td>
#       <td id="T_4e2ab_row9_col2" class="data row9 col2" >18.8</td>
#       <td id="T_4e2ab_row9_col3" class="data row9 col3" >63.3</td>
#       <td id="T_4e2ab_row9_col4" class="data row9 col4" >33.3</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row10_col0" class="data row10 col0" >Gemma 3 4B</td>
#       <td id="T_4e2ab_row10_col1" class="data row10 col1" >30.8</td>
#       <td id="T_4e2ab_row10_col2" class="data row10 col2" >18.9</td>
#       <td id="T_4e2ab_row10_col3" class="data row10 col3" >60.0</td>
#       <td id="T_4e2ab_row10_col4" class="data row10 col4" >30.0</td>
#     </tr>
#     <tr>
#       <td id="T_4e2ab_row11_col0" class="data row11 col0" >Gemma 3 12B</td>
#       <td id="T_4e2ab_row11_col1" class="data row11 col1" >37.5</td>
#       <td id="T_4e2ab_row11_col2" class="data row11 col2" >21.1</td>
#       <td id="T_4e2ab_row11_col3" class="data row11 col3" >58.9</td>
#       <td id="T_4e2ab_row11_col4" class="data row11 col4" >10.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Figure 4.4.3 — QA by question type
#
# Separating comparison, inference, temporal, and unanswerable questions reveals whether aggregate results are
# driven by one stratum. Token F1 is undefined for unanswerable questions and is therefore shown only where observed.

# %%
question_types = ["comparison", "inference", "temporal", "unanswerable"]
panels = [
    ("answer_correct", "Answer correctness"),
    ("over_abstention", "Over-abstention rate"),
]
question_type_regime_colors = {**REGIME_COLORS, "Native": OKABE_ITO["bluish_green"]}
fig, axes = plt.subplots(1, 2, figsize=(14, 4.8), constrained_layout=True)
width = 0.24
x = np.arange(len(question_types))
for ax, (metric, label) in zip(axes, panels):
    for offset, regime in enumerate(REGIME_ORDER):
        subset = qa_question_type.loc[qa_question_type["regime"].eq(regime)].set_index("question_type").reindex(question_types)
        ax.bar(x + (offset - 1) * width, subset[metric], width, color=question_type_regime_colors[regime], label=regime)
    ax.set_xticks(x, [item.title() for item in question_types])
    ax.set_ylabel(label)
    ax.set_ylim(0, 1)
    ax.yaxis.set_major_formatter(PercentFormatter(1.0))
axes[0].legend(loc="upper left", frameon=False, ncol=3)
save_figure(fig, "03_qa_by_question_type")
plt.show()

# %% [markdown]
# ## Figure 4.4.4 — Answer outcome composition
#
# The stacked bars partition answerable cases into correct answers, over-abstention, hallucination, and other
# incorrect answers. This distinguishes a conservative model from one that answers incorrectly with confidence.

# %%
answerable_rows = question_metrics.loc[question_metrics["answerable"].eq(True)].copy()
answerable_rows["outcome_group"] = np.select(
    [
        answerable_rows["answer_correct"].fillna(False).astype(bool),
        answerable_rows["over_abstention"].fillna(False).astype(bool),
        answerable_rows["hallucination"].fillna(False).astype(bool),
    ],
    ["Correct", "Over-abstention", "Hallucination"],
    default="Other incorrect",
)
outcome_order = ["Correct", "Over-abstention", "Hallucination", "Other incorrect"]
outcome_colors = {
    "Correct": OKABE_ITO["bluish_green"],
    "Over-abstention": OKABE_ITO["sky_blue"],
    "Hallucination": OKABE_ITO["vermillion"],
    "Other incorrect": OKABE_ITO["orange"],
}
outcome_summary = (
    answerable_rows.groupby(["regime", "outcome_group"], observed=True)
    .size().rename("count").reset_index()
)
outcome_summary["share"] = outcome_summary["count"] / outcome_summary.groupby("regime")["count"].transform("sum")
save_table(outcome_summary, "answer_outcome_composition")

pivot = outcome_summary.pivot(index="regime", columns="outcome_group", values="share").reindex(index=REGIME_ORDER, columns=outcome_order).fillna(0)
fig, ax = plt.subplots(figsize=(9.5, 5.8), constrained_layout=True)
bottom = np.zeros(len(pivot))
for outcome in outcome_order:
    values = pivot[outcome].to_numpy()
    ax.bar(pivot.index, values, bottom=bottom, color=outcome_colors[outcome], label=outcome)
    bottom += values
ax.set_ylabel("Share of answerable questions")
ax.set_ylim(0, 1)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.legend(frameon=False, ncol=2)
save_figure(fig, "04_answer_outcome_composition")
plt.show()

# %% [markdown]
# ## Figure 4.4.5 — Model-family-specific relationship between builder scale and QA improvement
#
# Points show the ER+RR−Native change in answer accuracy for individual builders; vertical bars represent 95%
# paired bootstrap confidence intervals. Panels separate model families, while dashed lines connect builders
# in ascending parameter-count order to show the observed within-family trajectories descriptively.

# %%
scale_qa = (
    qa_builder_effects.query(
        "contrast == 'Primary: ER+RR−Native' and metric == 'answer_correct'"
    )
    [["builder_key", "display_name", "family", "parameter_billions", "mean_difference", "ci_lower", "ci_upper"]]
    .copy()
)
save_table(scale_qa, "model_scale_primary_qa_effect")
family_order = ["gemma3", "qwen3", "qwen3.5"]
family_titles = {"gemma3": "Gemma 3", "qwen3": "Qwen3", "qwen3.5": "Qwen3.5"}

fig, axes = plt.subplots(1, 3, figsize=(15, 5.8), sharey=True, constrained_layout=True)
for ax, family in zip(axes, family_order):
    group = scale_qa.loc[scale_qa["family"].eq(family)].sort_values("parameter_billions")
    x = group["parameter_billions"].to_numpy()
    y = group["mean_difference"].to_numpy() * 100
    lower = group["ci_lower"].to_numpy() * 100
    upper = group["ci_upper"].to_numpy() * 100
    errors = np.vstack([y - lower, upper - y])
    ax.plot(x, y, linestyle="--", linewidth=1.2, color=FAMILY_COLORS[family], alpha=0.45, zorder=1)
    ax.errorbar(
        x, y, yerr=errors, fmt="o", markersize=7.5, capsize=3.5,
        color=FAMILY_COLORS[family], ecolor=FAMILY_COLORS[family],
        markeredgecolor="white", markeredgewidth=0.7, linewidth=1.5, zorder=3,
    )
    for row in group.itertuples():
        ax.annotate(
            row.display_name,
            (row.parameter_billions, row.mean_difference * 100),
            xytext=(0, 7), textcoords="offset points",
            ha="center", va="bottom", fontsize=7.5,
        )
    ax.axhline(0, color=OKABE_ITO["black"], linewidth=1)
    ax.set_xscale("log")
    ax.set_xticks(x, [f"{value:g}" for value in x])
    ax.tick_params(axis="x", which="minor", bottom=False, labelbottom=False)
    ax.grid(axis="y", alpha=0.22)
    ax.grid(axis="x", visible=False)
    ax.set_title(family_titles[family])
fig.supxlabel("Builder parameter count (billions, log scale)")
fig.supylabel(r"Answer accuracy change: $\mathrm{ER+RR} - \mathrm{Native}$ (pp)")
save_figure(fig, "05_model_scale_and_qa_effect")
plt.show()
